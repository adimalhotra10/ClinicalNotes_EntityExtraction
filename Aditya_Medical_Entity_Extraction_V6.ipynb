# %% [markdown]
# # 1. Importing Data

# %%
import scipy
import pandas as pd
import scispacy
import spacy
import re

# %%
data = pd.read_csv("ClinNotes.csv")
med_concepts = pd.read_csv("MedicalConcepts.csv")

#cleaning up
data['notes'] = data['notes'].apply(lambda x: re.sub('(\.,)', ". ", x))

# %%
sample=data.iloc[21][1]

# %%
sample
# Out:
# "CHIEF COMPLAINT: , Severe back pain and sleepiness. The patient is not a good historian and history was obtained from the patient's husband at bedside. HISTORY OF PRESENT ILLNESS:  ,The patient is a 76-year-old obese Caucasian female with past medical conditions that includes hypertension, history of urinary incontinence, dementia, and chronic back pain, basically brought by the husband to the emergency room because of having excruciating back pain.  As per the husband, the patient has this back pain for about almost 1 year and seeing Dr. X in Neurosurgery and had an epidural injection x2, and then the patient's pain somewhat got better between, but last time the patient went to see Dr. X, the patient given injection and the patient passed out, so the doctor stopped giving any other epidural injection.  The patient has severe pain and all in all, the patient cries at home.  As per the husband, the patient woke up in the morning with severe pain, unable to eat, drink today, and crying in the morning, so brought her to the emergency room for further evaluation.  The patient denied any history of fever, cough, chest pain, diarrhea, dysuria or polyuria.  While I was examining the patient, the patient explained about possible diagnosis and treatment plan and possible nursing home discharge for pain control.  The patient passed out for about 3 to 4 minutes, unable to respond to even painful stimuli.  The patient's heart rate went down to 50s and blood pressure was 92 systolic, so the patient was later on given IV fluid and blood pressure checked.  The patient woke up after 5 to 6 minutes, so the patient was later on evaluated for admission because of near syncopal episode. PAST MEDICAL CONDITIONS:,  Include hypertension, dementia, urinary incontinence, chronic back pain, and degenerative joint disease of the spine.  No history of diabetes, stroke or coronary artery disease. SURGICAL HISTORY: , Include left total hip replacement many years ago, history of hysterectomy, and appendectomy in the young age. ALLERGIES: , DENIED. CURRENT MEDICATIONS: , According to the list shows the patient takes hydrocodone 10/325 mg every 6 hours, Flexeril 10 mg p.o. at bedtime, and Xanax 0.25 mg p.o. 4 times a day.  The patient also takes Neurontin 200 mg 3 times a day, propranolol 10 mg twice a day, oxybutynin 5 mg p.o. twice a day, Namenda 10 mg p.o. daily, and Aricept 10 mg p.o. daily. SOCIAL HISTORY: , She lives with her husband, usually walks with a walker and wheelchair-bound, does not walk much as per the husband knows.  No history of alcohol abuse or smoking. PHYSICAL EXAMINATION:,GENERAL:  Currently lying in the bed without apparent distress, very lethargic. VITAL SIGNS:  Pulse rate of 55, blood pressure is 92/52, after IV fluid came up to 105/58. CHEST:  Shows bilateral air entry present, clear to auscultate. HEART:  S1 and S2 regular. ABDOMEN:  Soft, nondistended, and nontender. EXTREMITIES:  Shows the patient's straight leg raising to be only up to 30% causing the patient severe back pain. IMAGING: , The patient's x-ray of the lumbosacral spine done shows there is a L1 compression fracture with some osteophyte formation in the lumbar spine suggestive of degenerative joint disease. LABORATORY DATA: , The patient's lab test is not done currently, but previous lab test done in 3/2009 seems to be in acceptable range. IMPRESSION: , The patient, because of near syncopal episode and polypharmacy, almost passed out for about 3 to 4 minutes in front of me with a low blood pressure. 1.  Vasovagal syncope versus polypharmacy because of 3 to 4 medications and muscle relaxants. 2.  Osteoporosis of the spine with L1 compression fracture causing the patient severe pain. 3.  Hypertension, now hypotension. 4.  Incontinence of the bladder. 5.  Dementia, most likely Alzheimer type. PLAN AND SUGGESTION: , Initial plan was to send the patient to the nursing home, but because of the patient's low blood pressure and heart rate low, we will admit the patient to D ...

# %% [markdown]
# # 2. Entity Extraction

# %% [markdown]
# ## 2.1 Entity Extraction using scispacy - en_ner_bc5cdr_md

# %%
nlp = spacy.load("en_ner_bc5cdr_md")

# %%
doc = nlp(sample)

# %%
doc
# Out:
# CHIEF COMPLAINT: , Severe back pain and sleepiness.,The patient is not a good historian and history was obtained from the patient's husband at bedside.,HISTORY OF PRESENT ILLNESS:  ,The patient is a 76-year-old obese Caucasian female with past medical conditions that includes hypertension, history of urinary incontinence, dementia, and chronic back pain, basically brought by the husband to the emergency room because of having excruciating back pain.  As per the husband, the patient has this back pain for about almost 1 year and seeing Dr. X in Neurosurgery and had an epidural injection x2, and then the patient's pain somewhat got better between, but last time the patient went to see Dr. X, the patient given injection and the patient passed out, so the doctor stopped giving any other epidural injection.  The patient has severe pain and all in all, the patient cries at home.  As per the husband, the patient woke up in the morning with severe pain, unable to eat, drink today, and crying in the morning, so brought her to the emergency room for further evaluation.  The patient denied any history of fever, cough, chest pain, diarrhea, dysuria or polyuria.  While I was examining the patient, the patient explained about possible diagnosis and treatment plan and possible nursing home discharge for pain control.  The patient passed out for about 3 to 4 minutes, unable to respond to even painful stimuli.  The patient's heart rate went down to 50s and blood pressure was 92 systolic, so the patient was later on given IV fluid and blood pressure checked.  The patient woke up after 5 to 6 minutes, so the patient was later on evaluated for admission because of near syncopal episode.,PAST MEDICAL CONDITIONS:,  Include hypertension, dementia, urinary incontinence, chronic back pain, and degenerative joint disease of the spine.  No history of diabetes, stroke or coronary artery disease.,SURGICAL HISTORY: , Include left total hip replacement many years ago, history of hysterectomy, and appendectomy in the young age.,ALLERGIES: , DENIED.,CURRENT MEDICATIONS: , According to the list shows the patient takes hydrocodone 10/325 mg every 6 hours, Flexeril 10 mg p.o. at bedtime, and Xanax 0.25 mg p.o. 4 times a day.  The patient also takes Neurontin 200 mg 3 times a day, propranolol 10 mg twice a day, oxybutynin 5 mg p.o. twice a day, Namenda 10 mg p.o. daily, and Aricept 10 mg p.o. daily.,SOCIAL HISTORY: , She lives with her husband, usually walks with a walker and wheelchair-bound, does not walk much as per the husband knows.  No history of alcohol abuse or smoking.,PHYSICAL EXAMINATION:,GENERAL:  Currently lying in the bed without apparent distress, very lethargic.,VITAL SIGNS:  Pulse rate of 55, blood pressure is 92/52, after IV fluid came up to 105/58.,CHEST:  Shows bilateral air entry present, clear to auscultate.,HEART:  S1 and S2 regular.,ABDOMEN:  Soft, nondistended, and nontender.,EXTREMITIES:  Shows the patient's straight leg raising to be only up to 30% causing the patient severe back pain.,IMAGING: , The patient's x-ray of the lumbosacral spine done shows there is a L1 compression fracture with some osteophyte formation in the lumbar spine suggestive of degenerative joint disease.,LABORATORY DATA: , The patient's lab test is not done currently, but previous lab test done in 3/2009 seems to be in acceptable range.,IMPRESSION: , The patient, because of near syncopal episode and polypharmacy, almost passed out for about 3 to 4 minutes in front of me with a low blood pressure.,1.  Vasovagal syncope versus polypharmacy because of 3 to 4 medications and muscle relaxants.,2.  Osteoporosis of the spine with L1 compression fracture causing the patient severe pain.,3.  Hypertension, now hypotension.,4.  Incontinence of the bladder.,5.  Dementia, most likely Alzheimer type.,PLAN AND SUGGESTION: , Initial plan was to send the patient to the nursing home, but because of the patient's low blood pressure and heart rate low, we will admit the patient to DO ...

# %%
for ent in doc.ents:
    print(ent.text, ent.start_char, ent.end_char, ent.label_)
# Out:
# back pain 26 35 DISEASE
# sleepiness 40 50 DISEASE
# hypertension 277 289 DISEASE
# urinary incontinence 302 322 DISEASE
# dementia 324 332 DISEASE
# chronic back pain 338 355 DISEASE
# excruciating 430 442 DISEASE
# pain 448 452 DISEASE
# back pain 496 505 DISEASE
# pain 620 624 DISEASE
# pain 838 842 DISEASE
# cries 871 876 DISEASE
# pain 954 958 DISEASE
# fever 1111 1116 DISEASE
# cough 1118 1123 DISEASE
# chest pain 1125 1135 DISEASE
# diarrhea 1137 1145 DISEASE
# dysuria 1147 1154 DISEASE
# polyuria 1158 1166 DISEASE
# pain 1310 1314 DISEASE
# hypertension 1731 1743 DISEASE
# dementia 1745 1753 DISEASE
# urinary incontinence 1755 1775 DISEASE
# chronic back pain 1777 1794 DISEASE
# degenerative joint disease of the spine 1800 1839 DISEASE
# diabetes 1856 1864 DISEASE
# stroke 1866 1872 DISEASE
# coronary artery disease 1876 1899 DISEASE
# hydrocodone 2122 2133 CHEMICAL
# Flexeril 2159 2167 CHEMICAL
# Xanax 2195 2200 CHEMICAL
# Neurontin 2253 2262 CHEMICAL
# propranolol 2285 2296 CHEMICAL
# oxybutynin 2316 2326 CHEMICAL
# Namenda 2350 2357 CHEMICAL
# Aricept 2380 2387 CHEMICAL
# alcohol abuse 2562 2575 DISEASE
# smoking 2579 2586 CHEMICAL
# back pain 3020 3029 DISEASE
# compression fracture 3112 3132 DISEASE
# degenerative joint disease 3198 3224 DISEASE
# Vasovagal syncope 3528 3545 DISEASE
# Osteoporosis 3622 3634 DISEASE
# compression fracture 3656 3676 DISEASE
# pain 3704 3708 DISEASE
# Hypertension 3714 3726 DISEASE
# hypotension 3732 3743 DISEASE
# Dementia 3782 3790 DISEASE
# Alzheimer type 3804 3818 DISEASE
# KCl 4080 4083 CHEMICAL
# Protonix 4089 4097 CHEMICAL
# Namenda 4145 4152 CHEMICAL
# Aricept 4157 4164 CHEMICAL
# hydrocodone 4193 4204 CHEMICAL
# Flexeril 4223 4231 CHEMICAL
# gabapentin 4253 4263 CHEMICAL
# pain 4308 4312 DISEASE
# Percocet 4326 4334 CHEMICAL
# morphine 4352 4360 CHEMICAL
# calcium 4403 4410 CHEMICAL
# vitamin D 4416 4425 CHEMICAL
# pain 4724 4728 DISEASE

# %%
from spacy import displacy
displacy.render(doc, style='ent', jupyter=True)
# Out:
# <span class="tex2jax_ignore"><div class="entities" style="line-height: 2.5; direction: ltr">REASON FOR CONSULTATION:  ,Abnormal echocardiogram findings and followup.
# <mark class="entity" style="background: #ddd; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Shortness of breath
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">DISEASE</span>
# </mark>
# ,
# <mark class="entity" style="background: #ddd; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     congestive heart failure
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">DISEASE</span>
# </mark>
# , and
# <mark class="entity" style="background: #ddd; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     valvular insufficiency
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">DISEASE</span>
# </mark>
# . HISTORY OF PRESENT ILLNESS:  ,The patient is an 86-year-old female admitted for evaluation of
# <mark class="entity" style="background: #ddd; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     abdominal pain
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">DISEASE</span>
# </mark>
#  and bloody stools.  The patient has
# <mark class="entity" style="background: #ddd; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     colitis
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">DISEASE</span>
# </mark>
#  and also
# <mark class="entity" style="background: #ddd; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     diverticulitis
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">DISEASE</span>
# </mark>
# , undergoing treatment.  During the hospitalization, the patient complains of
# <mark class="entity" style="background: #ddd; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     shortness of breath
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">DISEASE</span>
# </mark>
# , which is worsening.  The patient underwent an echocardiogram, which shows severe
# <mark class="entity" style="background: #ddd; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     mitral regurgitation
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">DISEASE</span>
# </mark>
#  and also large
# <mark class="entity" style="background: #ddd; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     pleural effusion
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">DISEASE</span>
# </mark>
# .  This consultation is for further evaluation in this regard.  As per the patient, she is an 86-year-old female, has limited activity level.  She has been having
# <mark class="entity" style="background: #ddd; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     shortness of breath
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">DISEASE</span>
# </mark>
#  for many years.  She also was told that she has a
# <mark class="entity" style="background: #ddd; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     heart murmur
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">DISEASE</span>
# </mark>
# , which was not followed through on a regular basis. CORONARY RISK FACTORS: , History of
# <mark class="entity" style="background: #ddd; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     hypertension
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">DISEASE</span>
# </mark>
# , no history of
# <mark class="entity" style="background: #ddd; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     diabetes mellitus
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">DISEASE</span>
# </mark>
# , nonsmoker,
# <mark class="entity" style="background: #ddd; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     cholesterol
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">CHEMICAL</span>
# </mark>
#  status unclear, no prior history of
# <mark class="entity" style="background: #ddd; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     coronary artery disease
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">DISEASE</span>
# </mark>
# , and family history noncontributory. FAMILY HISTORY:  ,Nonsignificant. PAST SURGICAL HISTORY: , No major surgery. MEDICATIONS: , Presently on
# <mark class="entity" style="background: #ddd; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Lasix
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">CHEMICAL</span>
# </mark>
# ,
# <mark class="entity" style="background: #ddd; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     potassium
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">CHEMICAL</span>
# </mark>
#  supplementation,
# <mark class="entity" style="background: #ddd; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Levaquin
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">CHEMICAL</span>
# </mark>
# ,
# <mark class="entity" style="background: #ddd; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     hydralazine
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">CHEMICAL</span>
# </mark>
#  10 mg
# <mark class="entity" style="background: #ddd; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     b.i.d
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">CHEMICAL</span>
# </mark>
# .  antibiotic treatments, and thyroid supplementation. ALLERGIES:  ,
# <mark class="entity" style="background: #ddd; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     AMBIEN
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">CHEMICAL</span>
# </mark>
# ,
# <mark class="entity" style="background: #ddd; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     CARDIZEM
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">CHEMICAL</span>
# </mark>
# , AND IBUPROFEN. PERSONAL HISTORY:,  She is a nonsmoker.  Does not consume
# <mark class="entity

# %% [markdown]
# ### Extracting drug and dosage information

# %%
from spacy.matcher import Matcher

pattern = [{'ENT_TYPE':'CHEMICAL'}, {'LIKE_NUM': True}, {'IS_ASCII': True}]
matcher = Matcher(nlp.vocab)
matcher.add("DRUG_DOSE", [pattern])

# %%
for transcription in data['notes']:
    doc = nlp(transcription)
    matches = matcher(doc)
    for match_id, start, end in matches:
        string_id = nlp.vocab.strings[match_id]  # get string representation
        span = doc[start:end]  # the matched span
        print(string_id, start, end, span.text)
# Out:
# DRUG_DOSE 218 221 aspirin 325 mg
# DRUG_DOSE 410 413 penicillamine 250 mg
# DRUG_DOSE 420 423 metoprolol 12.5 mg
# DRUG_DOSE 428 431 aspirin 325 mg
# DRUG_DOSE 504 507 aspirin 81 mg
# DRUG_DOSE 521 524 Proscar 5 mg
# DRUG_DOSE 67 70 Xylocaine 1%
# DRUG_DOSE 412 415 hydrocodone 10/325 mg
# DRUG_DOSE 419 422 Flexeril 10 mg
# DRUG_DOSE 428 431 Xanax 0.25 mg
# DRUG_DOSE 443 446 Neurontin 200 mg
# DRUG_DOSE 451 454 propranolol 10 mg
# DRUG_DOSE 458 461 oxybutynin 5 mg
# DRUG_DOSE 467 470 Namenda 10 mg
# DRUG_DOSE 475 478 Aricept 10 mg
# DRUG_DOSE 823 826 Protonix 40 mg
# DRUG_DOSE 202 205 valium 5 mg
# DRUG_DOSE 207 210 DPH 1.0g.
# DRUG_DOSE 434 437 lorazepam 2 mg
# DRUG_DOSE 834 837 Trileptal 300 mg
# DRUG_DOSE 341 344 Dilaudid two tablets
# DRUG_DOSE 361 364 Neurontin 1600 mg
# DRUG_DOSE 377 380 Cytomel 25 mcg
# DRUG_DOSE 384 387 Seroquel 100 mg
# DRUG_DOSE 392 395 levothyroxine 300 mcg
# DRUG_DOSE 400 403 Prinivil 20 mg
# DRUG_DOSE 409 412 Mevacor 40 mg
# DRUG_DOSE 40 43 Dilantin 300 mg
# DRUG_DOSE 354 357 3 3 4
# DRUG_DOSE 355 358 3 4 4
# DRUG_DOSE 356 359 4 4 3
# DRUG_DOSE 357 360 4 3 4
# DRUG_DOSE 358 361 3 4 1
# DRUG_DOSE 359 362 4 1 1,LLE
# DRUG_DOSE 361 364 1,LLE 4 4
# DRUG_DOSE 362 365 4 4 4
# DRUG_DOSE 363 366 4 4+
# DRUG_DOSE 365 368 + 4+
# DRUG_DOSE 367 370 + 4+
# DRUG_DOSE 369 372 + 4 4
# DRUG_DOSE 370 373 4 4 4,There
# DRUG_DOSE 346 349 Solu-Cortef 1000mg
# DRUG_DOSE 450 453 Solu-Medrol 1g
# DRUG_DOSE 552 555 Praziquantel 3.6g
# DRUG_DOSE 563 566 Prednisone 60 mg
# DRUG_DOSE 669 672 Prednisone 60mg
# DRUG_DOSE 674 677 Zantac 50 IV
# DRUG_DOSE 679 682 Propulsid 20mg
# DRUG_DOSE 684 687 Enoxaparin 20mg
# DRUG_DOSE 370 373 Glucose 56,
# DRUG_DOSE 93 96 -6 lipomatosis
# DRUG_DOSE 120 123 glucose 78,
# DRUG_DOSE 328 331 Zoloft 50mg
# DRUG_DOSE 333 336 Lithium 300mg
# DRUG_DOSE 546 549 Creatinine 1.0.
# DRUG_DOSE 708 711 glucose 43,
# DRUG_DOSE 950 953 glucose 35,
# DRUG_DOSE 207 210 , 2)
# DRUG_DOSE 356 359 adductors 5/5,
# DRUG_DOSE 587 590 Creatinine 2.1,
# DRUG_DOSE 444 447 -4 posterior
# DRUG_DOSE 31 34 -4 disk
# DRUG_DOSE 294 297 -4.
# DRUG_DOSE 78 81 -4:
# DRUG_DOSE 650 653 Glucose 97,
# DRUG_DOSE 656 659 Na 134,
# DRUG_DOSE 659 662 K 4.0,
# DRUG_DOSE 662 665 Cr 1.3,
# DRUG_DOSE 668 671 CO2 24,
# DRUG_DOSE 703 706 B12 876,
# DRUG_DOSE 706 709 Folate 19.1.
# DRUG_DOSE 853 856 Glucose 57,
# DRUG_DOSE 899 902 Decadron 6mg
# DRUG_DOSE 272 275 Ortho-Novum 7-
# DRUG_DOSE 274 277 -7-
# DRUG_DOSE 276 279 -7 (
# DRUG_DOSE 802 805 Prednisone 60mg
# DRUG_DOSE 807 810 Tagamet 400mg
# DRUG_DOSE 192 195 Diflucan 100mg
# DRUG_DOSE 197 200 Acyclovir 400mg
# DRUG_DOSE 204 207 Stavudine 40mg
# DRUG_DOSE 209 212 Rifabutin 300mg
# DRUG_DOSE 647 650 Pyrimethamine 75mg
# DRUG_DOSE 652 655 Sulfadiazine 2 g
# DRUG_DOSE 168 171 Lopressor 25mg
# DRUG_DOSE 178 181 Premarin 1.25mg
# DRUG_DOSE 188 191 Oxybutynin 2.5mg
# DRUG_DOSE 193 196 isocyamine 0.125mg
# DRUG_DOSE 600 603 Sinemet 5 days
# DRUG_DOSE 261 264 Prednisone 80 mg
# DRUG_DOSE 358 361 Prednisone 80mg
# DRUG_DOSE 633 636 Cr 1.3,
# DRUG_DOSE 868 871 Fe 15,
# DRUG_DOSE 484 487 Thiamine 100mg
# DRUG_DOSE 489 492 Folate 1mg
# DRUG_DOSE 218 221 Lithium 300mg
# DRUG_DOSE 223 226 Accupril 20mg
# DRUG_DOSE 835 838 glucose 102 (
# DRUG_DOSE 1052 1055 ASA 325mg
# DRUG_DOSE 151 154 Rifampin 600mg
# DRUG_DOSE 156 159 Gentamicin 130mg
# DRUG_DOSE 786 789 glucose 76.
# DRUG_DOSE 124 127 Synthroid 100 mcg
# DRUG_DOSE 413 416 Lamotrigine 150 mg
# DRUG_DOSE 712 715 lamotrigine 150 mg
# DRUG_DOSE 176 179 Carbatrol 300 mg
# DRUG_DOSE 618 621 Carbatrol 200 b.i.d
# DRUG_DOSE 396 399 Aricept 10 mg
# DRUG_DOSE 403 406 carbidopa/levodopa 25/100 mg
# DRUG_DOSE 419 422 Colace 100 mg
# DRUG_DOSE 463 466 senna 8.6 mg
# DRUG_DOSE 470 473 Tylenol 650 mg
# DRUG_DOSE 477 480 promethazine 25 mg
# DRUG_DOSE 232 235 Mestinon 30mg
# DRUG_DOSE 310 313 Mestinon 30mg
# DRUG_DOSE 456 459 -4 demonstrates
# DRUG_DOSE 691 694 Solu-Medrol 500 mg
# DRUG_DOSE 778 781 prednisone 10 mg
# DRUG_DOSE 150 153 Flonase two sprays
# DRUG_DOSE 166 169 Zyrtec 10 mg
# DRUG_DOSE 313 316 ICA/PSV 0.955 m/second
# DRUG_DOSE 361 364 ICA/PSV 0.561,
# DRUG_DOSE 128 131 smoke 1 to
# DRUG_DOSE 226 229 Na 121 meq/L
# DRUG_DOSE 230 233 K 4.2 meq/L
# DRUG_DOSE 284 287 Na 35 meq/L,,COURSE
# DRUG_DOSE 443 446 Fludrocortisone 0.05 mg
# DRUG_DOSE 574 577 Valtrex 1 g
# DRUG_DOSE 195 198 -2 packs
# DRUG_DOSE 307 310 aspirin 81 mg
# DRUG_DOSE 441 444 thalidomide 100 mg/day
# DRUG_DOSE 663 666 Glucose 178 (
# DRUG_DOSE 607 610 Premarin 0.625 mg
# DRUG_DOSE 615 618 Aciphex 20 mg
# DRUG_DOSE 623 626 Toprol 50 mg
# DRUG_DOSE 453 456 Compazine 5 mg
# DRUG_DOSE 510 513 Compazine 10 mg
# DRUG_DOSE 160 163 Versed 2 mg
# DRUG_DOSE 164 167 fentanyl 50 mcg
# DRUG_DOSE 437 440 Protonix 40 mg
# DRUG_DOSE 112 115 Xylocaine 1%
# DRUG_DOSE 202 205 sodium 137,
# DRUG_DOSE 205 208 potassium 4.0,
# DRUG_DOSE 211 214 bicarbonate 29.7.
# DRUG_DOSE 279 282 Sodium 135,
# DRUG_DOSE 282 285 potassium 4.7,
# DRUG_DOSE 288 291 CO2 20,
# DRUG_DOSE 294 297 creatinine 0.3.
# DRUG_DOSE 446 449 tacrolimus 3.1 and
# DRUG_DOSE 520 523 Prograf 0.5 mg
# DRUG_DOSE 530 533 Valganciclovir 420 mg
# DRUG_DOSE 359 362 Sodium 131,
# DRUG_DOSE 362 365 potassium 3.9,
# DRUG_DOSE 225 228 Serevent two puffs
# DRUG_DOSE 230 233 Nasonex two sprays
# DRUG_DOSE 32 35 Xylocaine 1%
# DRUG_DOSE 479 482 iron 325 mg
# DRUG_DOSE 210 213 Diltiazem 30 mg
# DRUG_DOSE 215 218 pantoprazole 40 mg
# DRUG_DOSE 226 229 iron 325 mg
# DRUG_DOSE 421 424 CHEM 7:
# DRUG_DOSE 483 486 potassium 2.7,
# DRUG_DOSE 487 490 creatinine 0.4.
# DRUG_DOSE 278 281 Diovan 80/12.5 mg
# DRUG_DOSE 283 286 Lipitor 10 mg
# DRUG_DOSE 288 291 Lutein 20 mg
# DRUG_DOSE 294 297 acid 0.8 mg
# DRUG_DOSE 54 57 Versed 3,
# DRUG_DOSE 57 60 Demerol 25 and
# DRUG_DOSE 29 32 Marcaine 0.25%
# DRUG_DOSE 667 670 Marcaine 0.25%
# DRUG_DOSE 312 315 bilirubin 0.8.
# DRUG_DOSE 499 502 Glucose 134,
# DRUG_DOSE 506 509 creatinine 0.7.
# DRUG_DOSE 411 414 alk-phos 138 and
# DRUG_DOSE 335 338 Aspirin 81 mg
# DRUG_DOSE 343 346 Clopidogrel 75 mg
# DRUG_DOSE 351 354 Allopurinol 100 mg
# DRUG_DOSE 359 362 Levothyroxine 100 mcg
# DRUG_DOSE 368 371 Lisinopril 10 mg
# DRUG_DOSE 377 380 Metoprolol 25 mg
# DRUG_DOSE 386 389 Atorvastatin 10 mg
# DRUG_DOSE 109 112 nitroglycerin 0.4 mg
# DRUG_DOSE 358 361 Heparin 50 mg
# DRUG_DOSE 74 77 Xylocaine 1%
# DRUG_DOSE 69 72 Xylocaine 1%
# DRUG_DOSE 75 78 Xylocaine 1%
# DRUG_DOSE 79 82 Lidocaine 1%
# DRUG_DOSE 62 65 Atropine 0.25 mg
# DRUG_DOSE 225 228 -0 PDS
# DRUG_DOSE 325 328 Omeprazole 20 mg
# DRUG_DOSE 332 335 furosemide 20 mg
# DRUG_DOSE 339 342 citalopram 20 mg
# DRUG_DOSE 346 349 loratadine 10 mg
# DRUG_DOSE 784 787 creatinine 1.15,
# DRUG_DOSE 787 790 glucose 94,
# DRUG_DOSE 790 793 potassium 4.5,
# DRUG_DOSE 793 796 sodium 140,
# DRUG_DOSE 797 800 calcium 8.6.
# DRUG_DOSE 129 132 Digoxin 0.25 mg
# DRUG_DOSE 716 719 Sodium 139,
# DRUG_DOSE 719 722 potassium 3.5,
# DRUG_DOSE 726 729 CO2 22,
# DRUG_DOSE 738 741 glucose 84,
# DRUG_DOSE 19 22 doxycycline 150 mg
# DRUG_DOSE 29 32 hydroxychloroquine 200 mg
# DRUG_DOSE 413 416 B. 10.
# DRUG_DOSE 140 143 Prilosec 20 mg
# DRUG_DOSE 159 162 Plaquenil 200 mg
# DRUG_DOSE 165 168 Imuran 100 mg
# DRUG_DOSE 170 173 Advair one puff
# DRUG_DOSE 176 179 Premarin 0.3 mg
# DRUG_DOSE 181 184 Lipitor 10 mg
# DRUG_DOSE 188 191 Actonel 35 mg
# DRUG_DOSE 70 73 Benadryl 50 mg
# DRUG_DOSE 177 180 Lidocaine 1%
# DRUG_DOSE 252 255 Lidocaine 1%
# DRUG_DOSE 53 56 Ancef 1 g.
# DRUG_DOSE 59 62 Benadryl 50 mg
# DRUG_DOSE 66 69 Versed 3 mg
# DRUG_DOSE 73 76 Fentanyl 150 mcg
# DRUG_DOSE 233 236 Lidocaine 1%
# DRUG_DOSE 298 301 Lidocaine 1%
# DRUG_DOSE 37 40 Altrua 60,
# DRUG_DOSE 239 242 lidocaine 2%
# DRUG_DOSE 442 445 Sodium 126,
# DRUG_DOSE 445 448 potassium 4.3,
# DRUG_DOSE 451 454 CO2 26,
# DRUG_DOSE 454 457 glucose 371,
# DRUG_DOSE 461 464 creatinine 8.4.
# DRUG_DOSE 89 92 Lidocaine 2%
# DRUG_DOSE 116 119 Cr 0.5,
# DRUG_DOSE 122 125 Glucose 187,
# DRUG_DOSE 125 128 Na 140,
# DRUG_DOSE 128 131 K 4.0,
# DRUG_DOSE 613 616 Levaquin 750 mg
# DRUG_DOSE 665 668 Coreg 12.5 mg
# DRUG_DOSE 670 673 Lasix 40 mg
# DRUG_DOSE 791 794 Coreg 12.5 mg
# DRUG_DOSE 801 804 Lipitor 10 mg
# DRUG_DOSE 826 829 syrup 6.25 mg
# DRUG_DOSE 848 851 Zyrtec 10 mg
# DRUG_DOSE 858 861 Lamictal 100 mg
# DRUG_DOSE 868 871 Lamictal 150 mg
# DRUG_DOSE 892 895 Nexium 40 mg
# DRUG_DOSE 903 906 Neurontin 400 mg
# DRUG_DOSE 913 916 Lasix 40 mg
# DRUG_DOSE 923 926 Fentanyl 50 mcg
# DRUG_DOSE 940 943 carbonate 500 mg/vitamin
# DRUG_DOSE 970 973 Levaquin 750 mg
# DRUG_DOSE 144 147 Diovan 160 mg
# DRUG_DOSE 168 171 NovoLog 70/30,
# DRUG_DOSE 191 194 D3 one tablet
# DRUG_DOSE 583 586 potassium 2.8,
# DRUG_DOSE 589 592 bicarbonate 31,
# DRUG_DOSE 592 595 glucose 75,
# DRUG_DOSE 598 601 creatinine 0.8,
# DRUG_DOSE 601 604 calcium 8.6,
# DRUG_DOSE 605 608 bilirubin 3.2,
# DRUG_DOSE 550 553 -0 silk
# DRUG_DOSE 138 141 , 2,
# DRUG_DOSE 374 377 Amiodarone 200 mg
# DRUG_DOSE 513 516 saturation 100%
# DRUG_DOSE 743 746 sodium 135,
# DRUG_DOSE 746 749 potassium 4.2,
# DRUG_DOSE 752 755 bicarbonate 26,
# DRUG_DOSE 758 761 creatinine 0.8,
# DRUG_DOSE 560 563 Lovenox 60 mg
# DRUG_DOSE 605 608 Lovenox 60 mg
# DRUG_DOSE 632 635 Protonix 40 mg
# DRUG_DOSE 650 653 Levaquin 750 mg
# DRUG_DOSE 208 211 Aspirin 81 mg
# DRUG_DOSE 216 219 Spiriva 10 mcg
# DRUG_DOSE 399 402 nifedipine 10 mg
# DRUG_DOSE 143 146 Kerlone 10 mg
# DRUG_DOSE 552 555 Evista 60 mg
# DRUG_DOSE 962 965 Sodium 136,
# DRUG_DOSE 965 968 potassium 3.8,
# DRUG_DOSE 972 975 bicarbonate 27.
# DRUG_DOSE 979 982 creatinine 0.9.
# DRUG_DOSE 983 986 Glucose 110.
# DRUG_DOSE 987 990 Magnesium 2.5.
# DRUG_DOSE 241 244 Aspirin 325 mg
# DRUG_DOSE 251 254 Metoprolol 50 mg
# DRUG_DOSE 280 283 Nexium 40 mg
# DRUG_DOSE 290 293 Zocor 40 mg
# DRUG_DOSE 329 332 Plavix 600 mg
# DRUG_DOSE 219 222 hydralazine 10 mg

# %% [markdown]
# ## 2.2 Entity extraction with a different spacy model -  en_core_sci_sm

# %%
from spacy import displacy
from scispacy.abbreviation import AbbreviationDetector
from scispacy.umls_linking import UmlsEntityLinker

# %%
nlp = spacy.load("en_core_sci_sm") # just label entities.. Hence previous was better in that regard

# %%
doc = nlp(sample)

# %%
for ent in doc.ents:
    print(ent.text, ent.start_char, ent.end_char, ent.label_)
# Out:
# CHIEF 0 5 ENTITY
# COMPLAINT 6 15 ENTITY
# Severe back pain 19 35 ENTITY
# sleepiness 40 50 ENTITY
# patient 56 63 ENTITY
# historian 78 87 ENTITY
# history 92 99 ENTITY
# patient's 122 131 ENTITY
# bedside 143 150 ENTITY
# HISTORY OF PRESENT ILLNESS 152 178 ENTITY
# patient 186 193 ENTITY
# obese 211 216 ENTITY
# Caucasian 217 226 ENTITY
# female 227 233 ENTITY
# medical conditions 244 262 ENTITY
# hypertension 277 289 ENTITY
# history 291 298 ENTITY
# urinary incontinence 302 322 ENTITY
# dementia 324 332 ENTITY
# chronic back pain 338 355 ENTITY
# basically brought 357 374 ENTITY
# husband 382 389 ENTITY
# emergency room 397 411 ENTITY
# excruciating back pain 430 452 ENTITY
# husband 466 473 ENTITY
# patient 479 486 ENTITY
# back pain 496 505 ENTITY
# year 525 529 ENTITY
# seeing 534 540 ENTITY
# Dr. X 541 546 ENTITY
# Neurosurgery 550 562 ENTITY
# epidural 574 582 ENTITY
# patient's 610 619 ENTITY
# patient 672 679 ENTITY
# Dr. X 692 697 ENTITY
# patient 703 710 ENTITY
# injection 717 726 ENTITY
# patient 735 742 ENTITY
# doctor 762 768 ENTITY
# epidural 794 802 ENTITY
# injection 803 812 ENTITY
# patient 819 826 ENTITY
# severe 831 837 ENTITY
# pain 838 842 ENTITY
# patient 863 870 ENTITY
# cries 871 876 ENTITY
# home 880 884 ENTITY
# husband 898 905 ENTITY
# patient woke 911 923 ENTITY
# morning 934 941 ENTITY
# severe 947 953 ENTITY
# pain 954 958 ENTITY
# drink 975 980 ENTITY
# today 981 986 ENTITY
# crying 992 998 ENTITY
# morning 1006 1013 ENTITY
# emergency room 1037 1051 ENTITY
# evaluation 1064 1074 ENTITY
# patient 1081 1088 ENTITY
# history 1100 1107 ENTITY
# fever 1111 1116 ENTITY
# cough 1118 1123 ENTITY
# chest pain 1125 1135 ENTITY
# diarrhea 1137 1145 ENTITY
# dysuria 1147 1154 ENTITY
# polyuria 1158 1166 ENTITY
# I 1175 1176 ENTITY
# patient 1195 1202 ENTITY
# patient 1208 1215 ENTITY
# diagnosis 1241 1250 ENTITY
# treatment plan 1255 1269 ENTITY
# nursing home discharge 1283 1305 ENTITY
# pain control 1310 1322 ENTITY
# patient 1329 1336 ENTITY
# minutes 1365 1372 ENTITY
# painful 1400 1407 ENTITY
# stimuli 1408 1415 ENTITY
# patient's 1422 1431 ENTITY
# heart rate 1432 1442 ENTITY
# 50s 1456 1459 ENTITY
# blood pressure 1464 1478 ENTITY
# systolic 1486 1494 ENTITY
# patient 1503 1510 ENTITY
# IV fluid 1530 1538 ENTITY
# blood pressure 1543 1557 ENTITY
# patient 1572 1579 ENTITY
# minutes 1601 1608 ENTITY
# patient 1617 1624 ENTITY
# evaluated 1638 1647 ENTITY
# admission 1652 1661 ENTITY
# near 1673 1677 ENTITY
# syncopal episode 1678 1694 ENTITY
# PAST MEDICAL CONDITIONS 1696 1719 ENTITY
# hypertension 1731 1743 ENTITY
# dementia 1745 1753 ENTITY
# urinary incontinence 1755 1775 ENTITY
# chronic back pain 1777 1794 ENTITY
# degenerative joint disease 1800 1826 ENTITY
# spine 1834 1839 ENTITY
# No history 1842 1852 ENTITY
# diabetes 1856 1864 ENTITY
# stroke 1866 1872 ENTITY
# coronary artery disease 1876 1899 ENTITY
# SURGICAL HISTORY 1901 1917 ENTITY
# Include left total hip replacement 1921 1955 ENTITY
# years 1961 1966 ENTITY
# history 1972 1979 ENTITY
# hysterectomy 1983 1995 ENTITY
# appendectomy 2001 2013 ENTITY
# young age 2021 2030 ENTITY
# ALLERGIES 2032 2041 ENTITY
# DENIED 2045 2051 ENTITY
# CURRENT 2053 2060 ENTITY
# MEDICATIONS 2061 2072 ENTITY
# list 2093 2097 ENTITY
# patient 2108 2115 ENTITY
# hours 2152 2157 ENTITY
# Flexeril 2159 2167 ENTITY
# bedtime 2182 2189 ENTITY
# Xanax 2195 2200 ENTITY
# day 2224 2227 ENTITY
# patient 2234 2241 ENTITY
# Neurontin 2253 2262 ENTITY
# day 2280 2283 ENTITY
# propranolol 2285 2296 ENTITY
# day 2311 2314 ENTITY
# oxybutynin 2316 2326 ENTITY
# day 2345 2348 ENTITY
# Namenda 2350 2357 ENTITY
# daily 2369 2374 ENTITY
# daily 2399 2404 ENTITY
# SOCIAL HISTORY 2406 2420 ENTITY
# husband 2443 2450 ENTITY
# walks 2460 2465 ENTITY
# walker 2473 2479 ENTITY
# wheelchair-bound 2484 2500 ENTITY
# walk 2511 2515 ENTITY
# husband knows 2532 2545 ENTITY
# No history 2548 2558 ENTITY
# alcohol abuse 2562 2575 ENTITY
# smoking 2579 2586 ENTITY
# PHYSICAL EXAMINATION:,GENERAL 2588 2617 ENTITY
# lying 2630 2635 ENTITY
# bed 2643 2646 ENTITY
# apparent distress 2655 2672 ENTITY
# lethargic 2679 2688 ENTITY
# VITAL SIGNS 2690 2701 ENTITY
# Pulse rate 2704 2714 ENTITY
# blood pressure 2722 2736 ENTITY
# IV fluid 2753 2761 ENTITY
# CHEST 2781 2786 ENTITY
# bilateral 2795 2804 ENTITY
# auscultate 2833 2843 ENTITY
# HEART 2845 2850 ENTITY
# S2 2860 2862 ENTITY
# regular 2863 2870 ENTITY
# ABDOMEN 2872 2879 ENTITY
# Soft 2882 2886 ENTITY
# nondistended 2888 2900 ENTITY
# nontender 2906 2915 ENTITY
# EXTREMITIES 2917 2928 ENTITY
# patient's 2941 2950 ENTITY
# leg 2960 2963 ENTITY
# patient 3005 3012 ENTITY
# back pain 3020 3029 ENTITY
# IMAGING 3031 3038 ENTITY
# patient's 3046 3055 ENTITY
# x-ray 3056 3061 ENTITY
# lumbosacral spine 3069 3086 ENTITY
# L1 compression fracture 3109 3132 ENTITY
# osteophyte 3143 3153 ENTITY
# formation 3154 3163 ENTITY
# lumbar spine 3171 3183 ENTITY
# degenerative joint disease 3198 3224 ENTITY
# LABORATORY 3226 3236 ENTITY
# DATA 3237 3241 ENTITY
# patient's 3249 3258 ENTITY
# lab test 3259 3267 ENTITY
# lab test 3304 3312 ENTITY
# IMPRESSION 3361 3371 ENTITY
# patient 3379 3386 ENTITY
# near 3399 3403 ENTITY
# syncopal episode 3404 3420 ENTITY
# polypharmacy 3425 3437 ENTITY
# minutes 3474 3481 ENTITY
# low blood pressure 3504 3522 ENTITY
# Vasovagal syncope 3528 3545 ENTITY
# polypharmacy 3553 3565 ENTITY
# medications 3584 3595 ENTITY
# muscle 3600 3606 ENTITY
# relaxants 3607 3616 ENTITY
# Osteoporosis 3622 3634 ENTITY
# spine 3642 3647 ENTITY
# L1 compression fracture 3653 3676 ENTITY
# patient 3689 3696 ENTITY
# pain 3704 3708 ENTITY
# Hypertension 3714 3726 ENTITY
# hypotension 3732 3743 ENTITY
# Incontinence 3749 3761 ENTITY
# bladder 3769 3776 ENTITY
# Dementia 3782 3790 ENTITY
# Alzheimer type 3804 3818 ENTITY
# PLAN 3820 3824 ENTITY
# SUGGESTION 3829 3839 ENTITY
# plan 3851 3855 ENTITY
# patient 3872 3879 ENTITY
# nursing home 3887 3899 ENTITY
# patient's 3920 3929 ENTITY
# low blood pressure 3930 3948 ENTITY
# heart rate 3953 3963 ENTITY
# low 3964 3967 ENTITY
# patient 3987 3994 ENTITY
# DOU 3998 4001 ENTITY
# observation 4014 4025 ENTITY
# patient 4037 4044 ENTITY
# IV fluid 4048 4056 ENTITY
# normal saline 4058 4071 ENTITY
# KCl 4080 4083 ENTITY
# Protonix 4089 4097 ENTITY
# patient's 4135 4144 ENTITY
# Namenda 4145 4152 ENTITY
# Aricept 4157 4164 ENTITY
# patient's 4183 4192 ENTITY
# Flexeril 4223 4231 ENTITY
# I 4236 4237 ENTITY
# gabapentin 4253 4263 ENTITY
# moment 4272 4278 ENTITY
# patient's 4298 4307 ENTITY
# pain control 4308 4320 ENTITY
# Percocet 4326 4334 ENTITY
# morphine 4352 4360 ENTITY
# sulfate 4361 4368 ENTITY
# patient 4395 4402 ENTITY
# vitamin D 4416 4425 ENTITY
# physical therapy 4430 4446 ENTITY
# blood test 4470 4480 ENTITY
# management 4493 4503 ENTITY
# patient's 4525 4534 ENTITY
# test 4539 4543 ENTITY
# husband 4578 4585 ENTITY
# tomorrow 4591 4599 ENTITY
# patient 4607 4614 ENTITY
# alert 4634 4639 ENTITY
# awake 4644 4649 ENTITY
# nursing care 4680 4692 ENTITY
# home 4700 4704 ENTITY
# pain control 4724 4736 ENTITY

# %%
from spacy import displacy
displacy.render(next(doc.sents), style='dep', jupyter=True)
# Out:
# <span class="tex2jax_ignore"><svg xmlns="http://www.w3.org/2000/svg" xmlns:xlink="http://www.w3.org/1999/xlink" xml:lang="en" id="0c66e70d286d4387843f981365509f7b-0" class="displacy" width="1275" height="399.5" direction="ltr" style="max-width: none; height: 399.5px; color: #000000; background: #ffffff; font-family: Arial; direction: ltr">
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="309.5">
#     <tspan class="displacy-word" fill="currentColor" x="50">CHIEF</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="50">ADJ</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="309.5">
#     <tspan class="displacy-word" fill="currentColor" x="225">COMPLAINT: ,</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="225">NOUN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="309.5">
#     <tspan class="displacy-word" fill="currentColor" x="400">Severe</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="400">ADJ</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="309.5">
#     <tspan class="displacy-word" fill="currentColor" x="575">back</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="575">NOUN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="309.5">
#     <tspan class="displacy-word" fill="currentColor" x="750">pain</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="750">NOUN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="309.5">
#     <tspan class="displacy-word" fill="currentColor" x="925">and</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="925">CCONJ</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="309.5">
#     <tspan class="displacy-word" fill="currentColor" x="1100">sleepiness.</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1100">VERB</tspan>
# </text>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-0c66e70d286d4387843f981365509f7b-0-0" stroke-width="2px" d="M70,264.5 C70,177.0 215.0,177.0 215.0,264.5" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow-0c66e70d286d4387843f981365509f7b-0-0" class="displacy-label" startOffset="50%" side="left" fill="currentColor" text-anchor="middle">amod</textPath>
#     </text>
#     <path class="displacy-arrowhead" d="M70,266.5 L62,254.5 78,254.5" fill="currentColor"/>
# </g>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-0c66e70d286d4387843f981365509f7b-0-1" stroke-width="2px" d="M420,264.5 C420,177.0 565.0,177.0 565.0,264.5" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow-0c66e70d286d4387843f981365509f7b-0-1" class="displacy-label" startOffset="50%" side="left" fill="currentColor" text-anchor="middle">amod</textPath>
#     </text>
#     <path class="displacy-arrowhead" d="M420,266.5 L412,254.5 428,254.5" fill="currentColor"/>
# </g>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-0c66e70d286d4387843f981365509f7b-0-2" stroke-width="2px" d="M595,264.5 C595,177.0 740.0,177.0 740.0,264.5" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow-0c66e70d286d4387843f981365509f7b-0-2" class="displacy-label" startOffset="50%" side="left" fill="currentColor" text-anchor="middle">amod</textPath>
#     </text>
#     <path class="displacy-arrowhead" d="M595,266.5 L587,254.5 603,254.5" fill="currentColor"/>
# </g>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-0c66e70d286d4387843f981365509f7b-0-3" stroke-width="2px" d="M245,264.5 C245,2.0 750.0,2.0 750.0,264.5" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow-0c66e70d286d4387843f981365509f7b-0-3" class="displacy-label" startOffset="50%" side="left" fill="currentColor" text-anchor="middle">appos</textPath>
#     </text>
#     <path class="displacy-arrowhead" d="M750.0,266.5 L758.0,254.5 742.0,254.5" fill="currentColor"/>
# </g>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-0c66e70d286d4387843f981365509f7b-0-4" stroke-width="2px" d="M770,264.5 C770,177.0 915.0,177.0 915.0,264.5" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow-0c66e70d286d4387843f981365509f7b-0-4" class="displacy-label" startOffset="50%" side="left" fill="currentColor" text-anchor="middle">cc</textPath>
#     </text>
#     <path class="displacy-arrowhead" d="M915.0,266.5 L923.0,254.5 907.0,254.5" fill="currentColor"/>
# </g>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-0c66e70d286d4387843f981365509f7b-0-5" stroke-width="2px" d="M770,264.5 C770,89.5 1095.0,89.5 1095.0,264.5" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow-0c66e70d286d4387843f981365509f7b-0-5" class="displacy-label" startOffset="50%" side="left" fill="currentColor" text-anchor="middle">conj</textPath>
#     </text>
#     <path class="displacy-arrowhead" d="M1095.0,266.5 L1103.0,254.5 1087.0,254.5" fill="currentColor"/>
# </g>
# </svg></span>

# %% [markdown]
# Showing how links are established through the model for a given sentence.

# %% [markdown]
# # 3. Linking entities to UMLS CUIs
#
# #### Difficult to do it here in Google Colab but giving it a shot. Ideal way of doing this is through entity extraction using Metamap UMLS service

# %%
from scispacy.umls_linking import UmlsEntityLinker

# %%
linker = UmlsEntityLinker(resolve_abbreviations=True)

# %%
linker

# %%
nlp.add_pipe("scispacy_linker", config={"resolve_abbreviations": True, "linker_name": "umls"})

# %%
doc =nlp(sample)

# %%
doc
# Out:
# CHIEF COMPLAINT: , Severe back pain and sleepiness. The patient is not a good historian and history was obtained from the patient's husband at bedside. HISTORY OF PRESENT ILLNESS:  ,The patient is a 76-year-old obese Caucasian female with past medical conditions that includes hypertension, history of urinary incontinence, dementia, and chronic back pain, basically brought by the husband to the emergency room because of having excruciating back pain.  As per the husband, the patient has this back pain for about almost 1 year and seeing Dr. X in Neurosurgery and had an epidural injection x2, and then the patient's pain somewhat got better between, but last time the patient went to see Dr. X, the patient given injection and the patient passed out, so the doctor stopped giving any other epidural injection.  The patient has severe pain and all in all, the patient cries at home.  As per the husband, the patient woke up in the morning with severe pain, unable to eat, drink today, and crying in the morning, so brought her to the emergency room for further evaluation.  The patient denied any history of fever, cough, chest pain, diarrhea, dysuria or polyuria.  While I was examining the patient, the patient explained about possible diagnosis and treatment plan and possible nursing home discharge for pain control.  The patient passed out for about 3 to 4 minutes, unable to respond to even painful stimuli.  The patient's heart rate went down to 50s and blood pressure was 92 systolic, so the patient was later on given IV fluid and blood pressure checked.  The patient woke up after 5 to 6 minutes, so the patient was later on evaluated for admission because of near syncopal episode. PAST MEDICAL CONDITIONS:,  Include hypertension, dementia, urinary incontinence, chronic back pain, and degenerative joint disease of the spine.  No history of diabetes, stroke or coronary artery disease. SURGICAL HISTORY: , Include left total hip replacement many years ago, history of hysterectomy, and appendectomy in the young age. ALLERGIES: , DENIED. CURRENT MEDICATIONS: , According to the list shows the patient takes hydrocodone 10/325 mg every 6 hours, Flexeril 10 mg p.o. at bedtime, and Xanax 0.25 mg p.o. 4 times a day.  The patient also takes Neurontin 200 mg 3 times a day, propranolol 10 mg twice a day, oxybutynin 5 mg p.o. twice a day, Namenda 10 mg p.o. daily, and Aricept 10 mg p.o. daily. SOCIAL HISTORY: , She lives with her husband, usually walks with a walker and wheelchair-bound, does not walk much as per the husband knows.  No history of alcohol abuse or smoking. PHYSICAL EXAMINATION:,GENERAL:  Currently lying in the bed without apparent distress, very lethargic. VITAL SIGNS:  Pulse rate of 55, blood pressure is 92/52, after IV fluid came up to 105/58. CHEST:  Shows bilateral air entry present, clear to auscultate. HEART:  S1 and S2 regular. ABDOMEN:  Soft, nondistended, and nontender. EXTREMITIES:  Shows the patient's straight leg raising to be only up to 30% causing the patient severe back pain. IMAGING: , The patient's x-ray of the lumbosacral spine done shows there is a L1 compression fracture with some osteophyte formation in the lumbar spine suggestive of degenerative joint disease. LABORATORY DATA: , The patient's lab test is not done currently, but previous lab test done in 3/2009 seems to be in acceptable range. IMPRESSION: , The patient, because of near syncopal episode and polypharmacy, almost passed out for about 3 to 4 minutes in front of me with a low blood pressure. 1.  Vasovagal syncope versus polypharmacy because of 3 to 4 medications and muscle relaxants. 2.  Osteoporosis of the spine with L1 compression fracture causing the patient severe pain. 3.  Hypertension, now hypotension. 4.  Incontinence of the bladder. 5.  Dementia, most likely Alzheimer type. PLAN AND SUGGESTION: , Initial plan was to send the patient to the nursing home, but because of the patient's low blood pressure and heart rate low, we will admit the patient to DO ...

# %%
entity = doc.ents[1]

print("Name: ", entity)
# Out:
# Name:  mitral and tricuspid regurgitation

# %%
entity
# Out:
# (CHIEF,
#  COMPLAINT,
#  Severe back pain,
#  sleepiness,
#  patient,
#  historian,
#  history,
#  patient's,
#  bedside,
#  HISTORY OF PRESENT ILLNESS,
#  patient,
#  obese,
#  Caucasian,
#  female,
#  medical conditions,
#  hypertension,
#  history,
#  urinary incontinence,
#  dementia,
#  chronic back pain,
#  basically brought,
#  husband,
#  emergency room,
#  excruciating back pain,
#  husband,
#  patient,
#  back pain,
#  year,
#  seeing,
#  Dr. X,
#  Neurosurgery,
#  epidural,
#  patient's,
#  patient,
#  Dr. X,
#  patient,
#  injection,
#  patient,
#  doctor,
#  epidural,
#  injection,
#  patient,
#  severe,
#  pain,
#  patient,
#  cries,
#  home,
#  husband,
#  patient woke,
#  morning,
#  severe,
#  pain,
#  drink,
#  today,
#  crying,
#  morning,
#  emergency room,
#  evaluation,
#  patient,
#  history,
#  fever,
#  cough,
#  chest pain,
#  diarrhea,
#  dysuria,
#  polyuria,
#  I,
#  patient,
#  patient,
#  diagnosis,
#  treatment plan,
#  nursing home discharge,
#  pain control,
#  patient,
#  minutes,
#  painful,
#  stimuli,
#  patient's,
#  heart rate,
#  50s,
#  blood pressure,
#  systolic,
#  patient,
#  IV fluid,
#  blood pressure,
#  patient,
#  minutes,
#  patient,
#  evaluated,
#  admission,
#  near,
#  syncopal episode,
#  PAST MEDICAL CONDITIONS,
#  hypertension,
#  dementia,
#  urinary incontinence,
#  chronic back pain,
#  degenerative joint disease,
#  spine,
#  No history,
#  diabetes,
#  stroke,
#  coronary artery disease,
#  SURGICAL HISTORY,
#  Include left total hip replacement,
#  years,
#  history,
#  hysterectomy,
#  appendectomy,
#  young age,
#  ALLERGIES,
#  DENIED,
#  CURRENT,
#  MEDICATIONS,
#  list,
#  patient,
#  hours,
#  Flexeril,
#  bedtime,
#  Xanax,
#  day,
#  patient,
#  Neurontin,
#  day,
#  propranolol,
#  day,
#  oxybutynin,
#  day,
#  Namenda,
#  daily,
#  daily,
#  SOCIAL HISTORY,
#  husband,
#  walks,
#  walker,
#  wheelchair-bound,
#  walk,
#  husband knows,
#  No history,
#  alcohol abuse,
#  smoking,
#  PHYSICAL EXAMINATION:,GENERAL,
#  lying,
#  bed,
#  apparent distress,
#  lethargic,
#  VITAL SIGNS,
#  Pulse rate,
#  blood pressure,
#  IV fluid,
#  CHEST,
#  bilateral,
#  auscultate,
#  HEART,
#  S2,
#  regular,
#  ABDOMEN,
#  Soft,
#  nondistended,
#  nontender,
#  EXTREMITIES,
#  patient's,
#  leg,
#  patient,
#  back pain,
#  IMAGING,
#  patient's,
#  x-ray,
#  lumbosacral spine,
#  L1 compression fracture,
#  osteophyte,
#  formation,
#  lumbar spine,
#  degenerative joint disease,
#  LABORATORY,
#  DATA,
#  patient's,
#  lab test,
#  lab test,
#  IMPRESSION,
#  patient,
#  near,
#  syncopal episode,
#  polypharmacy,
#  minutes,
#  low blood pressure,
#  Vasovagal syncope,
#  polypharmacy,
#  medications,
#  muscle,
#  relaxants,
#  Osteoporosis,
#  spine,
#  L1 compression fracture,
#  patient,
#  pain,
#  Hypertension,
#  hypotension,
#  Incontinence,
#  bladder,
#  Dementia,
#  Alzheimer type,
#  PLAN,
#  SUGGESTION,
#  plan,
#  patient,
#  nursing home,
#  patient's,
#  low blood pressure,
#  heart rate,
#  low,
#  patient,
#  DOU,
#  observation,
#  patient,
#  IV fluid,
#  normal saline,
#  KCl,
#  Protonix,
#  patient's,
#  Namenda,
#  Aricept,
#  patient's,
#  Flexeril,
#  I,
#  gabapentin,
#  moment,
#  patient's,
#  pain control,
#  Percocet,
#  morphine,
#  sulfate,
#  patient,
#  vitamin D,
#  physical therapy,
#  blood test,
#  management,
#  patient's,
#  test,
#  husband,
#  tomorrow,
#  patient,
#  alert,
#  awake,
#  nursing care,
#  home,
#  pain control)

# %% [markdown]
# Challenge: For each entity, mapping to more than one CUI with probabilities.
#  Naive approach: Choose for each entity the one with the max probability, but can be a problem if the highest probability is not the best one.

# %%
for umls_ent in entity._.umls_ents:
    print(umls_ent)
# Out:
# ('C0040961', 0.8772329092025757)
# ('C0026266', 0.78549724817276)
# ('C4527152', 0.7252084016799927)

# %%
linker.umls.cui_to_entity['C0028754']
# Out:
# CUI: C0028754, Name: Obesity
# Definition: A status with BODY WEIGHT that is grossly above the acceptable or desirable weight, usually due to accumulation of excess FATS in the body. The standards may vary with age, sex, genetic or cultural background. In the BODY MASS INDEX, a BMI greater than 30.0 kg/m2 is considered obese, and a BMI greater than 40.0 kg/m2 is considered morbidly obese (MORBID OBESITY).
# TUI(s): T047
# Aliases (abbreviated, total: 15):
# 	 Adiposity, obese, Obesity (disorder), OBESITY, Obesity, unspecified, adiposity, OBESE, Obesity, NOS, Having too much body fat, Obese (finding)

# %%
#Find the entities and it's definition

entity = doc.ents
# Each entity is linked to UMLS with a score
# (currently just char-3gram matching).
for i in range(len(entity)):
    for umls_ent in entity[i]._.umls_ents:
        print(linker.umls.cui_to_entity[umls_ent[0]])
# Out:
# CUI: C1516470, Name: Chief cell
# Definition: One of three cell types that are found in the gastric or parathyroid glands, or in the carotid body. Gastric chief cells secrete pepsinogen and chymosin. Parathyroid chief cells secrete parathyroid hormone. Type 1 (chief) cells in the carotid body contain neurosecretory vesicles that may play a role in chemoreception.
# TUI(s): T025
# Aliases: (total: 2):
# 	 Chief Cells, Chief Cell
# CUI: C0039751, Name: Theft
# Definition: Unlawful act of taking property.
# TUI(s): T055
# Aliases (abbreviated, total: 11):
# 	 Thefts, steal, Stealing, steals, theft, thief, Theft, Theft (finding), stealing, Stealings
# CUI: C1706996, Name: Branch Chief
# Definition: A professional that is responsible for the direction and supervision of a division within a larger or more complex organization.
# TUI(s): T097
# Aliases: (total: 0):
#
# CUI: C0277786, Name: Chief complaint (finding)
# Definition: The primary reason for a patient visit.
# TUI(s): T033
# Aliases (abbreviated, total: 15):
# 	 Main Complain, CC, Complaint, Chief Complaint, complaint, Complaint, NOS, complaints present, complaints, Chief complaint, chief complaint
# CUI: C0277786, Name: Chief complaint (finding)
# Definition: The primary reason for a patient visit.
# TUI(s): T033
# Aliases (abbreviated, total: 15):
# 	 Main Complain, CC, Complaint, Chief Complaint, complaint, Complaint, NOS, complaints present, complaints, Chief complaint, chief complaint
# CUI: C0221586, Name: Spine complaint
# Definition: Spine complaint. Complaint is in the axial skeleton.
# TUI(s): T184
# Aliases: (total: 0):
#
# CUI: C0221588, Name: Muscle complaint
# Definition: Muscle complaint. Myalgia and/or muscle weakness not directly related to joint, spine or neurologic complaint.
# TUI(s): T184
# Aliases: (total: 0):
#
# CUI: C0238740, Name: severe back pain
# Definition: None
# TUI(s): T184
# Aliases: (total: 4):
# 	 BACK PAIN, SEVERE, back pain severe, back pains severe, back severe pain
# CUI: C4050465, Name: Severe Extremity Pain
# Definition: A response indicating that a person's extremity pain is severe: continuous and disabling and requiring continuous use of narcotic (or equivalent) medication.
# TUI(s): T033
# Aliases: (total: 3):
# 	 Severe, Severe Extremity Pain, Severe Pain
# CUI: C4521229, Name: Neck Pain Score 6
# Definition: A subjective score of 6 on a visual analogue scale that ranges from 0: No Pain to 10: Excruciating.
# TUI(s): T033
# Aliases: (total: 3):
# 	 Neck Pain Score 6, Severe Pain, 6 = Severe
# CUI: C4526778, Name: Neck Pain Score 8
# Definition: A subjective score of 8 on a visual analogue scale that ranges from 0: No Pain to 10: Excruciating.
# TUI(s): T033
# Aliases: (total: 2):
# 	 Very Severe Pain, 8= Very Severe
# CUI: C0004604, Name: Back Pain
# Definition: Acute or chronic pain located in the posterior regions of the THORAX; LUMBOSACRAL REGION; or the adjacent regions.
# TUI(s): T184
# Aliases (abbreviated, total: 54):
# 	 Aches, Back, dorsalgia, backache symptom, back pain over, PAIN BACK, backs pain, DORSAL PAIN, Pain in back, notalgia, BACKPAIN
# CUI: C0013144, Name: Drowsiness
# Definition: The sensation of struggling to remain awake.
# TUI(s): T033
# Aliases (abbreviated, total: 21):
# 	 Mental status, drowsy, Somnolent, Drowsy, somnolence, drowsy, SLEEPY, somnolent, Drowsiness, function (observable entity), DROWSY, Drowsy (finding)
# CUI: C2830004, Name: Somnolence
# Definition: Compelling urge to sleep.
# TUI(s): T048
# Aliases: (total: 6):
# 	 DROWSINESS, Sleepiness, SLEEPINESS, SOMNOLENCE, Somnolence, somnolence
# CUI: C0037313, Name: Sleep
# Definition: A readily reversible suspension of sensorimotor interaction with the environment, usually associated with recumbency and immobility.
# TUI(s): T040
# Aliases: (total: 8):
# 	 Sleep, Sleep, NOS, sleeping, sleep, Sleep, function, sleeps, Sleep, function (observable entity), Sleeping
# CUI: C4050403, Name: Ability to Sleep After Treatment question
# Definition: A question about an individual's ability to sleep since treatment.
# TUI(s): T170
# Aliases: (total: 2):
# 	 Ability to Sleep After Treatment, Sleeping
# CUI: C0917799, Name: Hypersomnia
# Definition: A sleep disorder characterized by excessive sleepiness.
# TUI(s): T047
# Aliases (abbreviated, total: 22):
# 	 increased sleep, too much sleep, Hypersomnia (disorder), Hypersomnia, unspecified, excessive sleeping, excessive sleep, Sleeping Excessive, excessive sleepiness, sleep too much, INCREASED SLEEPING
# CUI: C0030705, Name: Patients
# Definition: Individuals participating in the health care system for the purpose of receiving therapeutic, diagnostic, or preventive procedures.
# TUI(s): T101
# Aliases: (total: 8):
# 	 patient, Patients, PATIENT, LAY USER/PATIENT, Patient (person), patients, Patient, PT
# CUI: C1550655, Name: Specimen Type - Patient
# Definition: <p>A specimen that has been collected from a patient.</p>
# TUI(s): T031
# Aliases: (total: 1):
# 	 Patient
# CUI: C1578481, Name: Mail Claim Party - Patient
# Definition: None
# TUI(s): T078
# Aliases: (total: 1):
# 	 Patient
# CUI: C1578483, Name: Report source - Patient
# Definition: None
# TUI(s): T078
# Aliases: (total: 1):
# 	 Patient
# CUI: C1578484, Name: Relationship modifier - Patient
# Definition: None
# TUI(s): T078
# Aliases: (total: 1):
# 	 Patient
# CUI: C0335115, Name: Historian
# Definition: None
# TUI(s): T097
# Aliases: (total: 4):
# 	 Historian (occupation), historian, Historian, Historians
# CUI: C2004062, Name: History of previous events
# Definition: The aggregate of past events; the continuum of events occurring in succession leading from the past to the present; a record or narrative description of past events.
# TUI(s): T033
# Aliases: (total: 3):
# 	 documenting history, Historical, History
# CUI: C0019664, Name: History
# Definition: Record and study of past events.
# TUI(s): T090
# Aliases: (total: 3):
# 	 history, Histories, History
# CUI: C0019665, Name: Historical aspects qualifier
# Definition: Used for the historical aspects of any subject. It includes brief historical notes but excludes case histories.
# TUI(s): T169
# Aliases: (total: 2):
# 	 historical aspects, history
# CUI: C0262512, Name: History of present illness
# Definition: None
# TUI(s): T033
# Aliases: (total: 8):
# 	 hpi, HISTORY OF PRESENT ILLNESS, HO, History, NOS, History of (present illness), history, ho, hos
# CUI: C0262926, Name: Medical History
# Definition: A collection of information about a person's health. It may include information about allergies, illnesses and surgeries, and dates and results of physical exams, tests, screenings, and immunizations. It may also include information about medicines taken and about diet and exercise.
# TUI(s): T033
# Aliases (abbreviated, total: 17):
# 	 History of (contextual qualifier), personal history, History of (contextual qualifier) (qualifier value), History, Personal History, Medical History, History of, history of, personal health record, Personal Medical History
# CUI: C1705255, Name: Concept History
# Definition: The tracking of concept evolution over the lifetime of a vocabulary, includes concept creation, modification, merges, splits, and retirements.
# TUI(s): T077
# Aliases: (total: 4):
# 	 Concept History, NCI Thesaurus Concept History, EVS Concept Object History, History
# CUI: C0030706, Name: Patient Rights
# Definition: Fundamental claims of patients, as expressed in statutes, declarations, or generally accepted moral principles. (Bioethics Thesaurus) The term is used for discussions of patient rights as a group of many rights, as in a hospital's posting of a list of patient rights.
# TUI(s): T078
# Aliases (abbreviated, total: 21):
# 	 patient rights, Patients' Right, Patients Rights, Rights, Patients', Rights, Patient, Patient Right, Patient's Right, patients rights, Patient Rights, patients' rights
# CUI: C3698592, Name: Patient's home
# Definition: <p>location where healthcare was delivered which is the residence of the Patient.</p>
# TUI(s): T073
# Aliases: (total: 1):
# 	 Patient's Residence
# CUI: C4527299, Name: Patient Decision
# Definition: A position, opinion or judgment reached after consideration by a patient.
# TUI(s): T078
# Aliases: (total: 1):
# 	 Patient's Decision
# CUI: C0030707, Name: Patients' Rooms
# Definition: Rooms occupied by one or more individuals during a stay in a health facility. The concept includes aspects of environment, design, care, or economics.
# TUI(s): T073
# Aliases (abbreviated, total: 13):
# 	 Patient Rooms, Room, Patients', Client's room (environment), Room, Patient, Patient's room, Client's room, Patient Room, patient room, Patients' Room, Rooms, Patients'
# CUI: C0042801, Name: Visitors to Patients
# Definition: Patients' guests and rules for visiting.
# TUI(s): T098
# Aliases: (total: 8):
# 	 Patients Visitors, Visitor, Patients', Patient Visitors, Visitors to Patient, Visitors, Patients', Patient's Visitors, Patients' Visitor, Patients' Visitors
# CUI: C0262512, Name: History of present illness
# Definition: None
# TUI(s): T033
# Aliases: (total: 8):
# 	 hpi, HISTORY OF PRESENT ILLNESS, HO, History, NOS, History of (present illness), history, ho, hos
# CUI: C0030705, Name: Patients
# Definition: Individuals participating in the health care system for the purpose of receiving therapeutic, diagnostic, or preventive procedures.
# TUI(s): T101
# Aliases: (total: 8):
# 	 patient, Patients, PATIENT, LAY USER/PATIENT, Patient (person), patients, Patient, PT
# CUI: C1550655, Name: Specimen Type - Patient
# Definition: <p>A specimen that has been collected from a patient.</p>
# TUI(s): T031
# Aliases: (total: 1):
# 	 Patient
# CUI: C1578481, Name: Mail Claim Party - Patient
# Definition: None
# TUI(s): T078
# Aliases: (total: 1):
# 	 Patient
# CUI: C1578483, Name: Report source - Patient
# Definition: None
# TUI(s): T078
# Aliases: (total: 1):
# 	 Patient
# CUI: C1578484, Name: Relationship modifier - Patient
# Definition: None
# TUI(s): T078
# Aliases: (total: 1):
# 	 Patient
# CUI: C0028754, Name: Obesity
# Definition: A status with BODY WEIGHT that is grossly above the acceptable or desirable weight, usually due to accumulation of excess FATS in the body. The standards may vary with age, sex, genetic or cultural background. In the BODY MASS INDEX, a BMI greater than 30.0 kg/m2 is considered obese, and a BMI greater than 40.0 kg/m2 is considered morbidly obese (MORBID OBESITY).
# TUI(s): T047
# Aliases (abbreviated, total: 15):
# 	 Adiposity, obese, Obesity (disorder), OBESITY, Obesity, unspecified, adiposity, OBESE, Obesity, NOS, Having too much body fat, Obese (finding)
# CUI: C0025933, Name: Mice, Obese
# Definition: Mutant mice exhibiting a marked obesity coupled with overeating, hyperglycemia, hyperinsulinemia, marked insulin resistance, and infertility when in a homozygous state. They may be inbred or hybrid.
# TUI(s): T015
# Aliases: (total: 3):
# 	 Mouse, Obese, Obese Mice, Obese Mouse
# CUI: C0299583, Name: leptin
# Definition: Leptin (167 aa, ~16 kDa) is encoded by the human LEP gene. This protein is secreted by adipocytes and plays a role in the regulation of both appetite and body fat stores.
# TUI(s): T116, T125
# Aliases (abbreviated, total: 11):
# 	 Gene Product, Ob, Leptin (substance), Obese Gene Product, Ob Protein, Leptin, leptins, leptin, Gene Product, Obese, Ob Gene Product, Obese Protein
# CUI: C3853264, Name: Obese class I
# Definition: Body Mass Index (kg/m²) from 30.00 to 34.99 (WHO. Physical status: the use and interpretation of anthropometry. Report of a WHO Expert Committee. WHO Technical Report Series 854. Geneva: World Health Organization, 1995).
# TUI(s): T033
# Aliases: (total: 2):
# 	 Body mass index 30.00 to 34.99, Obese class I (finding)
# CUI: C0007457, Name: Caucasoid Race
# Definition: A group distinguished by classification according to physical features. This group, also called Europoid, centers around the Mediterranean Sea but includes other parts of Europe. (from Winick: Dictionary of Anthropology, 1972; American Heritage Dictionary, 2d College ed)
# TUI(s): T098
# Aliases (abbreviated, total: 23):
# 	 Caucasian Race, caucasian, Caucasian, White, Caucasoid Race, CAUCASIAN RACE, Occidental, Race, Caucasian, Caucasian Races, Caucasoid
# CUI: C0043157, Name: Caucasians
# Definition: An ethnic group of putative Caucasoid origin.
# TUI(s): T098
# Aliases (abbreviated, total: 17):
# 	 white people, whites, RaceWhite, White, white, CAUCASIANS, White - ethnic group, Whites, white race, caucasians
# CUI: C0221786, Name: white American
# Definition: any person whose home or birthplace is in the Americas, and whose ethnic background is in any of the original peoples of Europe, North Africa, or the Middle East.
# TUI(s): T098
# Aliases: (total: 6):
# 	 white American, caucasian American, Caucasian American, American whites, americans white, White American
# CUI: C5205683, Name: Northwest Caucasian Language
# Definition: A group of languages spoken in the northwestern Caucasus region, chiefly in three Russian republics (Adygea, Kabardino-Balkaria, Karachay-Cherkessia), the territory of Abkhazia, and Turkey, with smaller communities scattered throughout the Middle East.
# TUI(s): T171
# Aliases: (total: 3):
# 	 West Caucasian, Circassic, Abkhazo-Adyghean
# CUI: C0043210, Name: Woman
# Definition: Human females as cultural, psychological, sociological, political, and economic entities.
# TUI(s): T098
# Aliases (abbreviated, total: 14):
# 	 female humans, Girl, Human Females, Girls, Woman, women, human female, female, woman, Women
# CUI: C0086287, Name: Females
# Definition: An individual who reports belonging to the cultural gender role distinction of female.
# TUI(s): T032
# Aliases (abbreviated, total: 19):
# 	 Female, F, Female, NOS, Female Gender, Self Reported, Female structure, Females, Female gender, female, female sex, females
# CUI: C1705497, Name: Female, Self-Report
# Definition: An individual who reports to be female, the sex that ordinarily produces ova.
# TUI(s): T080
# Aliases: (total: 4):
# 	 Female, Self-Report, Female, Female Sex, Self-Report, Female, Self-Reported
# CUI: C1705498, Name: Female Phenotype
# Definition: An animal who is observed by researcher or clinician to be female, the sex that ordinarily produces ova.
# TUI(s): T080
# Aliases: (total: 3):
# 	 Female, FEMALE, Female Phenotype
# CUI: C1705489, Name: Male-to-Female Transsexual, Self-Report
# Definition: A person who was assigned to the male gender at birth based on physical characteristics but who self-identifies psychologically and emotionally as female.
# TUI(s): T033
# Aliases: (total: 10):
# 	 M-to-F, Transsexual Female, Male-to-Female Transsexual, Trans Female, Trans Woman, M2F, MTF, TF, Transwoman, Male-to-Female Transsexual, Self-Report
# CUI: C4745084, Name: Medical Condition
# Definition: Any kind of illness or circumstance which requires medical monitoring.
# TUI(s): T033
# Aliases: (total: 1):
# 	 Medical Condition
# CUI: C3714565, Name: Individual Physical Condition
# Definition: The physical condition of an individual.
# TUI(s): T032
# Aliases: (total: 7):
# 	 health physicals, Individual Physical Condition, physical health, physical condition, health physical, conditions physical, Physical Condition
# CUI: C0012634, Name: Disease
# Definition: A definite pathologic process with a characteristic set of signs and symptoms. It may affect the whole body or any of its parts, and its etiology, pathology, and prognosis may be known or unknown.
# TUI(s): T047
# Aliases (abbreviated, total: 26):
# 	 Disease, Clinical disease or syndrome, Clinical disease or syndrome present, NOS, disorder, Disorders, Disease or syndrome present, disease, Diseases and Disorders, Clinical disease AND/OR syndrome present, condition
# CUI: C0348080, Name: Condition
# Definition: A state of being, such as a state of health.
# TUI(s): T080
# Aliases: (total: 2):
# 	 Condition, Condition (attribute)
# CUI: C1705253, Name: Logical Condition
# Definition: An assumption on which rests the validity or effect of something else.
# TUI(s): T077
# Aliases: (total: 2):
# 	 Condition, Logical Condition
# CUI: C0020538, Name: Hypertensive disease
# Definition: Persistently high systemic arterial BLOOD PRESSURE. Based on multiple readings (BLOOD PRESSURE DETERMINATION), hypertension is currently defined as when SYSTOLIC PRESSURE is consistently greater than 140 mm Hg or when DIASTOLIC PRESSURE is consistently 90 mm Hg or more.
# TUI(s): T047
# Aliases (abbreviated, total: 57):
# 	 Hypertension, arterial, HYPERTENSION ARTERIAL, Elevated blood pressure, high bp, arterial hypertension systemic, hypertension, Hypertensive disease, NOS, HTN, hypertensive disorder, hyperpiesia
# CUI: C1963138, Name: Hypertension, CTCAE
# Definition: A disorder characterized by a pathological increase in blood pressure.
# TUI(s): T033
# Aliases: (total: 2):
# 	 Hypertension, Hypertension, CTCAE
# CUI: C0235222, Name: Diastolic hypertension
# Definition: Hypertension characterized diastolic blood pressure greater than 90 mmHg on two occasions.
# TUI(s): T047
# Aliases (abbreviated, total: 11):
# 	 dia hypertension, DIASTOLIC HYPERTENSION, diastolic htn, Diastolic hypertension, NOS, BLOOD PRESSURE INCREASE DIASTOLIC, dia htn, Diastolic hypertension (disorder), Hypertension, diastolic, Diastolic Hypertension, HYPERTENSION DIASTOLIC
# CUI: C1696708, Name: Prehypertension
# Definition: Blood pressure levels that are between normotension and hypertension. Individuals with prehypertension are at a higher risk for developing cardiovascular diseases. Generally, prehypertension is defined as SYSTOLIC PRESSURE of 131-139 mm Hg and/or DIASTOLIC PRESSURE of 81-89 when the optimal is 120/80 mm Hg. For diabetics and other metabolism diseases the prehypertension is around 110-129/70-79 mm Hg.
# TUI(s): T047
# Aliases: (total: 6):
# 	 Pre-Hypertensions, Pre-Hypertension, Pre Hypertension, Prehypertensions, Prehypertension, Prehypertension (finding)
# CUI: C0221155, Name: Systolic hypertension
# Definition: Abnormally high systolic blood pressure.
# TUI(s): T047
# Aliases: (total: 9):
# 	 systolic htn, Systolic hypertension (disorder), Systolic hypertension, systolic hypertension, Hypertension, systolic, sys htn, Systolic Hypertension, sys hypertension, SYSTOLIC HYPERTENSION
# CUI: C0019664, Name: History
# Definition: Record and study of past events.
# TUI(s): T090
# Aliases: (total: 3):
# 	 history, Histories, History
# CUI: C0019665, Name: Historical aspects qualifier
# Definition: Used for the historical aspects of any subject. It includes brief historical notes but excludes case histories.
# TUI(s): T169
# Aliases: (total: 2):
# 	 historical aspects, history
# CUI: C0262512, Name: History of present illness
# Definition: None
# TUI(s): T033
# Aliases: (total: 8):
# 	 hpi, HISTORY OF PRESENT ILLNESS, HO, History, NOS, History of (present illness), history, ho, hos
# CUI: C0262926, Name: Medical History
# Definition: A collection of information about a person's health. It may include information about allergies, illnesses and surgeries, and dates and results of physical exams, tests, screenings, and immunizations. It may also include information about medicines taken and about diet and exercise.
# TUI(s): T033
# Aliases (abbreviated, total: 17):
# 	 History of (contextual qualifier), personal history, History of (contextual qualifier) (qualifier value), History, Personal History, Medical History, History of, history of, personal health record, Personal Medical History
# CUI: C1705255, Name: Concept History
# Definition: The tracking of concept evolution over the lifetime of a vocabulary, includes concept creation, modification, merges, splits, and retirements.
# TUI(s): T077
# Aliases: (total: 4):
# 	 Concept History, NCI Thesaurus Concept History, EVS Concept Object History, History
# CUI: C0042024, Name: Urinary Incontinence
# Definition: Involuntary loss of URINE, such as leaking of urine. It is a symptom of various underlying pathological processes. Major types of incontinence include URINARY URGE INCONTINENCE and URINARY STRESS INCONTINENCE.
# TUI(s): T046
# Aliases (abbreviated, total: 44):
# 	 URINATION INVOLUNTARY, Unable to control bladder, loss of bladder control, bladder incontinent, Urinary Incontinence, urinary incontinence, BLADDER INCONTINENCE, Urine incontinence, incontinent of urine, leaking urine
# CUI: C4553924, Name: Urinary Incontinence, CTCAE 5.0
# Definition: A disorder characterized by inability to control the flow of urine from the bladder.
# TUI(s): T033
# Aliases: (total: 2):
# 	 Urinary Incontinence, CTCAE_5, Urinary incontinence
# CUI: C0150399, Name: Urinary incontinence care
# Definition: Actions performed to control the inability to retain and/or involuntary retain urine
# TUI(s): T058
# Aliases: (total: 2):
# 	 Urinary Incontinence Care, Urinary incontinence care (regime/therapy)
# CUI: C0150045, Name: Urge Incontinence
# Definition: Involuntary discharge of URINE that is associated with an abrupt and strong desire to void. It is usually related to the involuntary contractions of the detrusor muscle of the bladder (detrusor hyperreflexia or detrusor instability).
# TUI(s): T033
# Aliases (abbreviated, total: 19):
# 	 Urinary Reflex Incontinence, Urge incontinence of urine (finding), Urge Urinary Incontinence, urinary urge incontinence, incontinence urge, Urinary Incontinence, Urge, Urge Incontinence, Lack of bladder control if desire resisted, Urinary urge incontinence, Urge urinary incontinence
# CUI: C0042025, Name: Urinary Stress Incontinence
# Definition: Involuntary discharge of URINE as a result of physical activities that increase abdominal pressure on the URINARY BLADDER without detrusor contraction or overdistended bladder. The subtypes are classified by the degree of leakage, descent and opening of the bladder neck and URETHRA without bladder contraction, and sphincter deficiency.
# TUI(s): T047
# Aliases (abbreviated, total: 26):
# 	 Genuine stress incontinence, Urinary stress incontinence, Stress bladder incontinence, Genuine stress incontinence (finding), incontinence stress urinary, Stress Incontinence, Urinary, Urinary Incontinence, Stress, Incontinence, Urinary Stress, GSI - Genuine stress incontinence, incontinence urinary stress
# CUI: C0011265, Name: Presenile dementia
# Definition: The presence of dementia in an individual younger than age sixty five.
# TUI(s): T048
# Aliases (abbreviated, total: 15):
# 	 pre senile dementia, Dementia, Presenile, DEMENTIA, PRESENILE, Pre-Senile Dementia, dementia presenile, Presenile dementia, NOS, presenile dementia, pre-senile dementia, Pre-senile dementia, dementia
# CUI: C0497327, Name: Dementia
# Definition: An acquired organic mental disorder with loss of intellectual abilities of sufficient severity to interfere with social or occupational functioning. The dysfunction is multifaceted and involves memory, behavior, personality, judgment, attention, spatial relations, language, abstract thought, and other executive functions. The intellectual decline is usually progressive, and initially spares the level of consciousness.
# TUI(s): T048
# Aliases (abbreviated, total: 22):
# 	 DEMENTIA, Dementias, dementia disorder, dementia, AMENTIA, Amentia, Dementia, Organic dementia, Dementia, unspecified, amentia
# CUI: C0338462, Name: Semantic Dementia
# Definition: A progressive loss of the ability to remember the meaning of words, faces and objects. [ICM:PCaroppo, PMID:24966676]
# TUI(s): T048
# Aliases: (total: 5):
# 	 Semantic dementia, Dementia, Semantic, Dementias, Semantic, Semantic Dementias, Semantic dementia (disorder)
# CUI: C0001849, Name: AIDS Dementia Complex
# Definition: A neurologic condition associated with the ACQUIRED IMMUNODEFICIENCY SYNDROME and characterized by impaired concentration and memory, slowness of hand movements, ATAXIA, incontinence, apathy, and gait difficulties associated with HIV-1 viral infection of the central nervous system. Pathologic examination of the brain reveals white matter rarefaction, perivascular infiltrates of lymphocytes, foamy macrophages, and multinucleated giant cells. (From Adams et al., Principles of Neurology, 6th ed, pp760-1; N Engl J Med, 1995 Apr 6;332(14):934-40)
# TUI(s): T047
# Aliases (abbreviated, total: 34):
# 	 AIDS dementia, Acquired immune deficiency syndrome dementia complex, Dementia Complex, AIDS Related, HIV Dementias, Complex, AIDS Dementia, HIV-Associated Cognitive Motor Complex, HIV dementia, AIDS with dementia, NOS, HIV Dementia, Dementia associated with AIDS
# CUI: C0740418, Name: Chronic back pain
# Definition: None
# TUI(s): T184
# Aliases: (total: 5):
# 	 back chronic pain, back chronic pains, chronic back pain, Chronic back pain (finding), back pain chronic
# CUI: C0150055, Name: Chronic pain
# Definition: Aching sensation that persists for more than a few months. It may or may not be associated with trauma or disease, and may persist after the initial injury has healed. Its localization, character, and timing are more vague than with acute pain.
# TUI(s): T184
# Aliases: (total: 8):
# 	 Chronic Pains, Pain, Chronic, Pains, Chronic, Chronic pain (finding), Chronic pain, Long-lasting pain, Chronic Pain, chronic pain
# CUI: C0004604, Name: Back Pain
# Definition: Acute or chronic pain located in the posterior regions of the THORAX; LUMBOSACRAL REGION; or the adjacent regions.
# TUI(s): T184
# Aliases (abbreviated, total: 54):
# 	 Aches, Back, dorsalgia, backache symptom, back pain over, PAIN BACK, backs pain, DORSAL PAIN, Pain in back, notalgia, BACKPAIN
# CUI: C4553945, Name: Back Pain, CTCAE 5.0
# Definition: A disorder characterized by a sensation of marked discomfort in the back region.
# TUI(s): T033
# Aliases: (total: 2):
# 	 Back pain, Back Pain, CTCAE_5
# CUI: C0242664, Name: husband
# Definition: A male partner in marriage.
# TUI(s): T099
# Aliases: (total: 6):
# 	 Husband, husbands, Husbands, husband, HUSBAND, Husband (person)
# CUI: C0555049, Name: Husband left home
# Definition: An indication that a male, married individual who is or was living with another person left their shared home.
# TUI(s): T033
# Aliases: (total: 3):
# 	 Husband left home (finding), Husband left home, Husband Left Home
# CUI: C0003052, Name: Animal Husbandry
# Definition: The science of breeding, feeding and care of domestic animals; includes housing and nutrition.
# TUI(s): T090
# Aliases: (total: 7):
# 	 Husbandry, Animal, Animal husbandry, Animal husbandry (procedure), Animal Husbandry, Husbandries, Animal, animal husbandry, Animal Husbandries
# CUI: C0562508, Name: Accident and Emergency department
# Definition: Hospital department responsible for the administration and provision of immediate medical or surgical care to the emergency patient.
# TUI(s): T073, T093
# Aliases (abbreviated, total: 52):
# 	 EMERGENCY ROOM, emergency service hospital, Accident and Emergency Department, A & E - Accident and Emergency Department, Hospital Services, Emergency, Service, Emergency Hospital, Service Emergency, Hospital, Units, Emergency, Hospital Emergency Services, Rooms, Emergency
# CUI: C1546435, Name: Encounter Referral Source - emergency room
# Definition: None
# TUI(s): T078
# Aliases: (total: 1):
# 	 Emergency room
# CUI: C0085125, Name: Emergency Nursing
# Definition: The specialty or practice of nursing in the care of patients admitted to the emergency department.
# TUI(s): T091
# Aliases (abbreviated, total: 11):
# 	 emergency room nursing, Emergency Room Nursing, Emergency Nursing, Emergency nursing, Nursing, Emergency, ED Nursing, Nursing, Emergency Room, emergencies nursing, ER Nursing, emergency nursing
# CUI: C4728259, Name: emergency room treatment
# Definition: <p>To perform one or more operations on information for provision of immediately needed health care for an emergent condition in an emergency room or similar emergent care context by end users provisioned for this purpose, which does not constitute as policy override such as in a "Break the Glass" purpose of use.</p><p>Map:<i></i>Partially Maps to ISO 14265 Classification Term "Emergency care provision to an individual subject of care" described as "To inform persons needing to provide health care services to the subject of care urgently, possibly needing to over-ride the policies and consents pertaining to Purpose 1 above." Purpose 1 is equivalent to HL7 treatment purpose of use: "Clinical care provision to an individual subject of care" described as "To inform persons or processes responsible for providing health care services to the subject of care."</p><p>The ISO description conflates both of the proposed specializations of HL7 ETREAT: break the glass and the typically broader access to health information normally available to providers who are provisioned for emergency workflows on a regular basis, e.g., Emergency Room providers. Examples of greater access than is normally accessible by providers based on the need to know are access to sensitive information for which access typically requires a patient's consent. This is not an override of a patient's dissent to disclose sensitive information in cases where the applicable policy waives the need for that consent to access this information. In US, Title 38 Section 7332 and 42 CFR Part 2 both permit emergency access without the need to override a patient's consent directive; rather, this access is a limitation to the patient's right to dissent from disclosure.</p><p>There is a semantic gap in concepts. This classification term is described as activities â€œto inform personsâ€? rather than the rationale for performing actions/operations on information related to the activity.</p>
# TUI(s): T058
# Aliases: (total: 0):
#
# CUI: C0013956, Name: Emergency Situation
# Definition: A sudden unforeseen crisis that requires immediate action.
# TUI(s): T067
# Aliases: (total: 7):
# 	 emergencies, Emergency, emergency situations, Emergency Situation, emergency, EMERGENCY, emergency situation
# CUI: C4522208, Name: Neck Pain Score 10
# Definition: A subjective score of 10 on a visual analogue scale that ranges from 0: No Pain to 10: Excruciating.
# TUI(s): T033
# Aliases: (total: 3):
# 	 Neck Pain Score 10, Excruciating Pain, 10 = Excruciating
# CUI: C4055051, Name: Excruciating
# Definition: Intensely painful.
# TUI(s): T080
# Aliases: (total: 0):
#
# CUI: C0242664, Name: husband
# Definition: A male partner in marriage.
# TUI(s): T099
# Aliases: (total: 6):
# 	 Husband, husbands, Husbands, husband, HUSBAND, Husband (person)
# CUI: C0555049, Name: Husband left home
# Definition: An indication that a male, married individual who is or was living with another person left their shared home.
# TUI(s): T033
# Aliases: (total: 3):
# 	 Husband left home (finding), Husband left home, Husband Left Home
# CUI: C0003052, Name: Animal Husbandry
# Definition: The science of breeding, feeding and care of domestic animals; includes housing and nutrition.
# TUI(s): T090
# Aliases: (total: 7):
# 	 Husbandry, Animal, Animal husbandry, Animal husbandry (procedure), Animal Husbandry, Husbandries, Animal, animal husbandry, Animal Husbandries
# CUI: C0030705, Name: Patients
# Definition: Individuals participating in the health care system for the purpose of receiving therapeutic, diagnostic, or preventive procedures.
# TUI(s): T101
# Aliases: (total: 8):
# 	 patient, Patients, PATIENT, LAY USER/PATIENT, Patient (person), patients, Patient, PT
# CUI: C1550655, Name: Specimen Type - Patient
# Definition: <p>A specimen that has been collected from a patient.</p>
# TUI(s): T031
# Aliases: (total: 1):
# 	 Patient
# CUI: C1578481, Name: Mail Claim Party - Patient
# Definition: None
# TUI(s): T078
# Aliases: (total: 1):
# 	 Patient
# CUI: C1578483, Name: Report source - Patient
# Definition: None
# TUI(s): T078
# Aliases: (total: 1):
# 	 Patient
# CUI: C1578484, Name: Relationship modifier - Patient
# Definition: None
# TUI(s): T078
# Aliases: (total: 1):
# 	 Patient
# CUI: C0004604, Name: Back Pain
# Definition: Acute or chronic pain located in the posterior regions of the THORAX; LUMBOSACRAL REGION; or the adjacent regions.
# TUI(s): T184
# Aliases (abbreviated, total: 54):
# 	 Aches, Back, dorsalgia, backache symptom, back pain over, PAIN BACK, backs pain, DORSAL PAIN, Pain in back, notalgia, BACKPAIN
# CUI: C1963071, Name: Back Pain, CTCAE 3.0
# Definition: None
# TUI(s): T033
# Aliases: (total: 2):
# 	 Back pain, Back Pain, CTCAE_3
# CUI: C4553945, Name: Back Pain, CTCAE 5.0
# Definition: A disorder characterized by a sensation of marked discomfort in the back region.
# TUI(s): T033
# Aliases: (total: 2):
# 	 Back pain, Back Pain, CTCAE_5
# CUI: C0024031, Name: Low Back Pain
# Definition: Acute or chronic pain in the lumbar or sacral regions, which may be associated with musculo-ligamentous SPRAINS AND STRAINS; INTERVERTEBRAL DISK DISPLACEMENT; and other conditions.
# TUI(s): T184
# Aliases (abbreviated, total: 46):
# 	 Pain, Lower Back, Lumbalgia, Low back derangement syndrome, Low Back Pains, LOW BACK PAIN, LUMBAGO, low backache, Back Ache, Low, Back Pains, Low, Lower Back Pains
# CUI: C0439234, Name: year
# Definition: A period of time that it takes for Earth to make a complete revolution around the sun, approximately 365 days; a specific one year period.
# TUI(s): T079
# Aliases: (total: 9):
# 	 a, year, YYYY, YEARS, year (qualifier value), yr, years, Annum, Year
# CUI: C1561543, Name: Transaction counts and value totals - year
# Definition: <p>Transaction counts and value totals for each calendar year within the date range specified.</p>
# TUI(s): T170
# Aliases: (total: 1):
# 	 year
# CUI: C1561544, Name: Precision - year
# Definition: None
# TUI(s): T078
# Aliases: (total: 1):
# 	 year
# CUI: C0439508, Name: per year
# Definition: A frequency rate of occurrences of something within a period of time equal to three hundred sixty-five days.
# TUI(s): T079
# Aliases (abbreviated, total: 11):
# 	 per year (qualifier value), Every Year, per years, /a, per year, PA, Per Year, /year, /Year, Per Annum
# CUI: C4086728, Name: Past Year
# Definition: A period of time consisting of the 12 months before the present.
# TUI(s): T079
# Aliases: (total: 1):
# 	 Past Year
# CUI: C0042789, Name: Vision
# Definition: The series of events required for an organism to receive a visual stimulus, convert it to a molecular signal, and recognize and characterize the signal. Visual stimuli are detected in the form of photons and are processed to form an image. [GOC:ai]
# TUI(s): T040
# Aliases (abbreviated, total: 20):
# 	 Visual function, functions visual, vision, sees, Vision, NOS, sense of sight, Vision, Visual function (observable entity), Ocular Vision, visual function
# CUI: C0871317, Name: Seeing Eye Dog
# Definition: <p><b>Description:</b>Dogs trained to assist persons who are seeing impaired or blind.</p>
# TUI(s): T015
# Aliases: (total: 3):
# 	 Seeing, seeing eye dogs, dogs eye seeing
# CUI: C0233763, Name: Hallucinations, Visual
# Definition: Optical perception of an object, person or event in the absence of a corresponding stimulus.
# TUI(s): T184
# Aliases (abbreviated, total: 18):
# 	 Visual hallucination, Visual hallucinations (finding), visual hallucinations, Visual Hallucinations, seeing thing, Hallucination, visual, VISUAL HALLUCINATION, visual hallucination, Hallucination, Visual, seeing things
# CUI: C3665386, Name: Abnormal vision
# Definition: Disturbance of eyesight.
# TUI(s): T033
# Aliases (abbreviated, total: 16):
# 	 VISION ABNORMAL, Problem sight, Loss of vision, Problem seeing, Abnormal vision, Visual loss, cannot see properly, Abnormal vision (finding), Partial sight, subnormal vision
# CUI: C2348314, Name: Doctor - Title
# Definition: A courtesy title for a person who has received a doctorate degree or who practices medicine.
# TUI(s): T170
# Aliases: (total: 2):
# 	 Dr., Doctor
# CUI: C0027926, Name: Science of neurosurgery
# Definition: A surgical specialty concerned with the treatment of diseases and disorders of the brain, spinal cord, and peripheral and sympathetic nervous system.
# TUI(s): T091
# Aliases: (total: 6):
# 	 Neurosurgeries, neurosurgery, Neurological Surgery, Neurosurgery, Neurosurgery (qualifier value), science of neurosurgery
# CUI: C0524850, Name: Neurosurgical Procedures
# Definition: Surgery performed on the nervous system or its parts.
# TUI(s): T061
# Aliases (abbreviated, total: 29):
# 	 neurosurgery, neurological surgeries, GENERAL OPERATIVE PROCEDURES ON THE NERVOUS SYSTEM, Surgical Procedure, Neurologic, neurosurgical procedures, Operative procedure on nervous system, NOS, neurological surgery, Neurologic Surgical Procedure, Operations on the nervous system, OPERATIVE PROCEDURES ON THE NERVOUS SYSTEM
# CUI: C0237427, Name: Neurosurgeon
# Definition: Qualified medical professionals who specialize in surgical treatment of diseases of the BRAIN and other parts of the NERVOUS SYSTEM.
# TUI(s): T097
# Aliases (abbreviated, total: 14):
# 	 Surgeons, Neurological, Neurosurgeons, Neurosurgeon, Neurosurgeon (occupation), Physicians; Physician/Osteopath; Surgery, Neurological, surgeon neuro, Neurological Surgeons, neuro surgeon, surgeon, neuro-, Neurological Surgeon
# CUI: C0228134, Name: Spinal epidural space
# Definition: Space between the dura mater and the walls of the vertebral canal.
# TUI(s): T030
# Aliases (abbreviated, total: 15):
# 	 Spinal extradural space, EPIDURAL SPACE, Epidural Spinal Canal Space, Spinal epidural space, Structure of epidural space of spine, Epidural Space, Spatium epidurale (Spinalis), Structure of epidural space of spine (body structure), Spatium peridurale, epidural
# CUI: C0592511, Name: Epidural Route of Drug Administration
# Definition: Administration of the drug in the epidural space, usually at the lumbar level of the spine. The drug must initially cross the dura mater before exerting its effect on the nervous system components. The drug is also subject to uptake into the rich epidural plexus of veins. Uptake and distribution after epidural administration resembles that seen after intramuscular injection. The portion of drug that is not taken into the vascular compartment is available to cross the dura. Hydrophilicity is a major component in the pharmacokinetics of drug transfer into the subdural space.
# TUI(s): T169
# Aliases: (total: 9):
# 	 EPIDURAL, Epidural route (qualifier value), EPIDUR, Epidural, Epidural route, epidural use, EpiduralRoute, Epidural Route of Administration, Epidural use
# CUI: C0812144, Name: Medication administration: epidural
# Definition: None
# TUI(s): T061
# Aliases: (total: 6):
# 	 Administration of drug or medicament via epidural route (procedure), Medication administration: epidural, Administration of drug or medicament via epidural route, epidural injection, epidural, epidurals
# CUI: C1550254, Name: Body Parts - Epidural
# Definition: None
# TUI(s): T023
# Aliases: (total: 1):
# 	 Epidural
# CUI: C0014536, Name: Epidural Neoplasms
# Definition: Neoplasms located in the space between the vertebral PERIOSTEUM and DURA MATER surrounding the SPINAL CORD. Tumors in this location are most often metastatic in origin and may cause neurologic deficits by mass effect on the spinal cord or nerve roots or by interfering with blood supply to the spinal cord.
# TUI(s): T191
# Aliases (abbreviated, total: 26):
# 	 Neoplasm of Epidural Spinal Canal, Extradural Spinal Canal Neoplasm, Tumor of the Epidural Spinal Canal, Neoplasm of Extradural Spinal Canal, Extradural Spinal Neoplasms, Tumor of Epidural Spinal Canal, Epidural Spinal Canal Tumors, Neoplasm of the Extradural Spinal Canal, Extradural Spinal Canal Neoplasms, Epidural Spinal Canal Tumor
# CUI: C0030706, Name: Patient Rights
# Definition: Fundamental claims of patients, as expressed in statutes, declarations, or generally accepted moral principles. (Bioethics Thesaurus) The term is used for discussions of patient rights as a group of many rights, as in a hospital's posting of a list of patient rights.
# TUI(s): T078
# Aliases (abbreviated, total: 21):
# 	 patient rights, Patients' Right, Patients Rights, Rights, Patients', Rights, Patient, Patient Right, Patient's Right, patients rights, Patient Rights, patients' rights
# CUI: C3698592, Name: Patient's home
# Definition: <p>location where healthcare was delivered which is the residence of the Patient.</p>
# TUI(s): T073
# Aliases: (total: 1):
# 	 Patient's Residence
# CUI: C4527299, Name: Patient Decision
# Definition: A position, opinion or judgment reached after consideration by a patient.
# TUI(s): T078
# Aliases: (total: 1):
# 	 Patient's Decision
# CUI: C0030707, Name: Patients' Rooms
# Definition: Rooms occupied by one or more individuals during a stay in a health facility. The concept includes aspects of environment, design, care, or economics.
# TUI(s): T073
# Aliases (abbreviated, total: 13):
# 	 Patient Rooms, Room, Patients', Client's room (environment), Room, Patient, Patient's room, Client's room, Patient Room, patient room, Patients' Room, Rooms, Patients'
# CUI: C0042801, Name: Visitors to Patients
# Definition: Patients' guests and rules for visiting.
# TUI(s): T098
# Aliases: (total: 8):
# 	 Patients Visitors, Visitor, Patients', Patient Visitors, Visitors to Patient, Visitors, Patients', Patient's Visitors, Patients' Visitor, Patients' Visitors
# CUI: C0030705, Name: Patients
# Definition: Individuals participating in the health care system for the purpose of receiving therapeutic, diagnostic, or preventive procedures.
# TUI(s): T101
# Aliases: (total: 8):
# 	 patient, Patients, PATIENT, LAY USER/PATIENT, Patient (person), patients, Patient, PT
# CUI: C1550655, Name: Specimen Type - Patient
# Definition: <p>A specimen that has been collected from a patient.</p>
# TUI(s): T031
# Aliases: (total: 1):
# 	 Patient
# CUI: C1578481, Name: Mail Claim Party - Patient
# Definition: None
# TUI(s): T078
# Aliases: (total: 1):
# 	 Patient
# CUI: C1578483, Name: Report source - Patient
# Definition: None
# TUI(s): T078
# Aliases: (total: 1):
# 	 Patient
# CUI: C1578484, Name: Relationship modifier - Patient
# Definition: None
# TUI(s): T078
# Aliases: (total: 1):
# 	 Patient
# CUI: C2348314, Name: Doctor - Title
# Definition: A courtesy title for a person who has received a doctorate degree or who practices medicine.
# TUI(s): T170
# Aliases: (total: 2):
# 	 Dr., Doctor
# CUI: C0030705, Name: Patients
# Definition: Individuals participating in the health care system for the purpose of receiving therapeutic, diagnostic, or preventive procedures.
# TUI(s): T101
# Aliases: (total: 8):
# 	 patient, Patients, PATIENT, LAY USER/PATIENT, Patient (person), patients, Patient, PT
# CUI: C1550655, Name: Specimen Type - Patient
# Definition: <p>A specimen that has been collected from a patient.</p>
# TUI(s): T031
# Aliases: (total: 1):
# 	 Patient
# CUI: C1578481, Name: Mail Claim Party - Patient
# Definition: None
# TUI(s): T078
# Aliases: (total: 1):
# 	 Patient
# CUI: C1578483, Name: Report source - Patient
# Definition: None
# TUI(s): T078
# Aliases: (total: 1):
# 	 Patient
# CUI: C1578484, Name: Relationship modifier - Patient
# Definition: None
# TUI(s): T078
# Aliases: (total: 1):
# 	 Patient
# CUI: C0021485, Name: Injection of therapeutic agent
# Definition: None
# TUI(s): T061
# Aliases (abbreviated, total: 14):
# 	 Injection of therapeutic agent, NOS, injection procedures, Shot, Injection of therapeutic agent, Injection of medication, NOS, injection, administration of injection, injections, Injection of drug, NOS, injection procedure
# CUI: C1272883, Name: Injection
# Definition: A substance intended for injection.
# TUI(s): T122
# Aliases: (total: 10):
# 	 injection product, Injectable, INJ, Injectable Dosage Form, injection, Injection, Injectable Dose Form, INJECTION, Inj, injection device
# CUI: C1533685, Name: Injection procedure
# Definition: Administration using positive pressure and a needle or other equipment to drive a substance into the body.
# TUI(s): T061
# Aliases: (total: 10):
# 	 Administration of injection, INJECTIONS, Injection, NOS, Injection - action (qualifier value), injection, Injection, Injections, Injection Administration, Injection - action, Injection (procedure)
# CUI: C1828121, Name: Injection Route of Drug Administration
# Definition: Introduction of substances into the body using a needle and syringe.
# TUI(s): T169
# Aliases: (total: 6):
# 	 Injectable, injection, Injections, Injection, Injection Route of Administration, Injection Procedure
# CUI: C4049935, Name: Injection Dosing Unit
# Definition: A dosing unit equal to the amount of active ingredient(s) contained in an injection.
# TUI(s): T081
# Aliases: (total: 2):
# 	 Injection, Injection Dosing Unit
# CUI: C0030705, Name: Patients
# Definition: Individuals participating in the health care system for the purpose of receiving therapeutic, diagnostic, or preventive procedures.
# TUI(s): T101
# Aliases: (total: 8):
# 	 patient, Patients, PATIENT, LAY USER/PATIENT, Patient (person), patients, Patient, PT
# CUI: C1550655, Name: Specimen Type - Patient
# Definition: <p>A specimen that has been collected from a patient.</p>
# TUI(s): T031
# Aliases: (total: 1):
# 	 Patient
# CUI: C1578481, Name: Mail Claim Party - Patient
# Definition: None
# TUI(s): T078
# Aliases: (total: 1):
# 	 Patient
# CUI: C1578483, Name: Report source - Patient
# Definition: None
# TUI(s): T078
# Aliases: (total: 1):
# 	 Patient
# CUI: C1578484, Name: Relationship modifier - Patient
# Definition: None
# TUI(s): T078
# Aliases: (total: 1):
# 	 Patient
# CUI: C0031831, Name: Physicians
# Definition: Individuals licensed to practice medicine.
# TUI(s): T097
# Aliases (abbreviated, total: 17):
# 	 Physicians, physician, doctor, doctors, RoleClassPhysician, PHYSICIAN, medical doctor, physicians, medical doctors, Medical doctor (occupation)
# CUI: C2348314, Name: Doctor - Title
# Definition: A courtesy title for a person who has received a doctorate degree or who practices medicine.
# TUI(s): T170
# Aliases: (total: 2):
# 	 Dr., Doctor
# CUI: C0260087, Name: Otolaryngologist
# Definition: Physicians specializing in the treatment of disorders of the ear, nose, and throat.
# TUI(s): T097
# Aliases: (total: 5):
# 	 Otolaryngologists, otolaryngologist, ENT doctor, otolaryngologists, Otolaryngologist
# CUI: C1512027, Name: Doctorate Degree
# Definition: The Doctor's Degree is the highest award a student can earn for graduate study. The doctor's degree classification includes such degrees in any field.
# TUI(s): T170
# Aliases: (total: 4):
# 	 Doctor's Degree, Doctoral Degree, Doctorate Degree, Doctorate
# CUI: C3831596, Name: Adverse Event Doctor Visit
# Definition: The situation that occurs when an individual must visit a physician because of an adverse event.
# TUI(s): T051
# Aliases: (total: 1):
# 	 Doctor Visit
# CUI: C0228134, Name: Spinal epidural space
# Definition: Space between the dura mater and the walls of the vertebral canal.
# TUI(s): T030
# Aliases (abbreviated, total: 15):
# 	 Spinal extradural space, EPIDURAL SPACE, Epidural Spinal Canal Space, Spinal epidural space, Structure of epidural space of spine, Epidural Space, Spatium epidurale (Spinalis), Structure of epidural space of spine (body structure), Spatium peridurale, epidural
# CUI: C0592511, Name: Epidural Route of Drug Administration
# Definition: Administration of the drug in the epidural space, usually at the lumbar level of the spine. The drug must initially cross the dura mater before exerting its effect on the nervous system components. The drug is also subject to uptake into the rich epidural plexus of veins. Uptake and distribution after epidural administration resembles that seen after intramuscular injection. The portion of drug that is not taken into the vascular compartment is available to cross the dura. Hydrophilicity is a major component in the pharmacokinetics of drug transfer into the subdural space.
# TUI(s): T169
# Aliases: (total: 9):
# 	 EPIDURAL, Epidural route (qualifier value), EPIDUR, Epidural, Epidural route, epidural use, EpiduralRoute, Epidural Route of Administration, Epidural use
# CUI: C0812144, Name: Medication administration: epidural
# Definition: None
# TUI(s): T061
# Aliases: (total: 6):
# 	 Administration of drug or medicament via epidural route (procedure), Medication administration: epidural, Administration of drug or medicament via epidural route, epidural injection, epidural, epidurals
# CUI: C1550254, Name: Body Parts - Epidural
# Definition: None
# TUI(s): T023
# Aliases: (total: 1):
# 	 Epidural
# CUI: C0014536, Name: Epidural Neoplasms
# Definition: Neoplasms located in the space between the vertebral PERIOSTEUM and DURA MATER surrounding the SPINAL CORD. Tumors in this location are most often metastatic in origin and may cause neurologic deficits by mass effect on the spinal cord or nerve roots or by interfering with blood supply to the spinal cord.
# TUI(s): T191
# Aliases (abbreviated, total: 26):
# ...
# CUI: C0699718, Name: Physical therapy (field)
# Definition: None
# TUI(s): T091
# Aliases: (total: 7):
# 	 physical therapy, physical therapy (field), Physiotherapy, Physiotherapy (qualifier value), field physical therapy, Physical therapy, fields physical therapy
# CUI: C0949766, Name: Physical therapy
# Definition: The use of exercises and physical activities to help condition muscles and restore strength and movement. For example, physical therapy can be used to restore arm and shoulder movement and build back strength after breast cancer surgery.
# TUI(s): T061
# Aliases (abbreviated, total: 42):
# 	 Physical Medicine Procedure, physical technique therapy, physical therapies, Physical therapy procedure, Physiotherapies (Techniques), physiotherapy, Physical Therapy Technique, Physical Therapy - Physiotherapy, Physical Therapy Modality, Physical therapy procedure, NOS
# CUI: C1547999, Name: Diagnostic Service Section ID - Physical Therapy
# Definition: None
# TUI(s): T170
# Aliases: (total: 1):
# 	 Physical Therapy
# CUI: C1948126, Name: physical therapy care
# Definition: Assessment/diagnosis and treatment provided by physical therapists and their staff or assistants.
# TUI(s): T058
# Aliases: (total: 0):
#
# CUI: C0687581, Name: Physical therapy table
# Definition: A multi-function physical therapy table is a device intended for medical purposes that consists of a motorized table equipped to provide patients with heat, traction, and muscle relaxation therapy.
# TUI(s): T074
# Aliases: (total: 2):
# 	 TABLE, PHYSICAL THERAPY, MULTI FUNCTION, Physical therapy table (physical object)
# CUI: C0018941, Name: Hematologic Tests
# Definition: Tests used in the analysis of the hemic system.
# TUI(s): T059
# Aliases (abbreviated, total: 37):
# 	 blood tests, Hematology test, Hematology test (procedure), hematology tests, hematologic technique, Haematology - general, hematological test, blood testing, Test, Hematologic, hematologic testing
# CUI: C0994779, Name: Blood test device
# Definition: None
# TUI(s): T074
# Aliases: (total: 1):
# 	 BLOOD TEST
# CUI: C0005776, Name: blood flow measurement
# Definition: techniques used to measure velocity and amount of blood flow and circulation in the living system.
# TUI(s): T060
# Aliases: (total: 9):
# 	 Vascular function test, Flow tests - blood, blood flow test, blood flow measurement, Blood flow tests, Circulatory function tests (procedure), Circ. function test, Circulatory function tests, Vascular function test (procedure)
# CUI: C0005767, Name: Blood
# Definition: The body fluid that circulates in the vascular system (BLOOD VESSELS). Whole blood includes PLASMA and BLOOD CELLS.
# TUI(s): T031
# Aliases: (total: 8):
# 	 Blood, Portion of blood, Haema, Blood, NOS, BLOOD, blood, Sanguis, Blood (substance)
# CUI: C0005768, Name: In Blood
# Definition: Used for the presence or analysis of substances in the blood; also for examination of, or changes in, the blood in disease states. It excludes serodiagnosis, for which the subheading "diagnosis" is used, and serology, for which "immunology" is used.
# TUI(s): T031
# Aliases: (total: 1):
# 	 blood
# CUI: C0001554, Name: Administration occupational activities
# Definition: Performing or possessing executive duties; acting as a supervisor or manager.
# TUI(s): T057
# Aliases: (total: 6):
# 	 administration [executive duty], Administration (navigational concept), Administration, Management, administration, Administration, Management
# CUI: C0376636, Name: Disease Management
# Definition: A broad approach to appropriate coordination of the entire disease treatment process that often involves shifting away from more expensive inpatient and acute care to areas such as preventive medicine, patient counseling and education, and outpatient care. This concept includes implications of appropriate versus inappropriate therapy on the overall cost and clinical outcome of a particular disease. (From Hosp Pharm 1995 Jul;30(7):596)
# TUI(s): T058
# Aliases: (total: 7):
# 	 Managements, Disease, management, Management, Disease, Disease management, Disease Managements, Disease Management, disease management
# CUI: C1273870, Name: Management procedure
# Definition: The act of conducting, controlling or supervising something.
# TUI(s): T057
# Aliases: (total: 9):
# 	 Supervision, Management procedure, Management procedure (procedure), management procedure, management procedures, Management, Oversight, Managed, Managing
# CUI: C3273539, Name: Management Occupations
# Definition: A class of professional or vocational positions of employment that involve management.
# TUI(s): T090
# Aliases: (total: 2):
# 	 Management Occupations, Management
# CUI: C2735310, Name: Care management
# Definition: <p>To perform analytics, evaluation and other secondary uses of treatment and healthcare related information to manage the quality, efficacy, patient safety, population health, and cost effectiveness of healthcare delivery. Explicitly excludes the use of information to organize the delivery of health care for care coordination and case management, or to provide healthcare treatment.</p><p><i>Usage Note:</i>The concept of care management is narrower than the list of activities related to more general organizational objectives such as provider profiling, education of healthcare and non-healthcare professionals; insurance underwriting, premium rating, reinsurance; organizational legal, medical review, auditing, compliance and fraud and abuse detection; business planning, development, and restructuring; fund-raising; and customer service.</p><p><i>Map:</i>Maps to ISO 14265 Classification Term "Health service management and quality assurance" described as "To inform persons or processes responsible for determining the availability, quality, safety, equity and cost-effectiveness of health care services."</p><p>There is a semantic gap in concepts. This classification term is described as activities, i.e., "to inform persons" or "to inform processes" rather than the rationale for performing actions/operations on information related to the activity.</p>
# TUI(s): T058
# Aliases: (total: 1):
# 	 care management
# CUI: C0030706, Name: Patient Rights
# Definition: Fundamental claims of patients, as expressed in statutes, declarations, or generally accepted moral principles. (Bioethics Thesaurus) The term is used for discussions of patient rights as a group of many rights, as in a hospital's posting of a list of patient rights.
# TUI(s): T078
# Aliases (abbreviated, total: 21):
# 	 patient rights, Patients' Right, Patients Rights, Rights, Patients', Rights, Patient, Patient Right, Patient's Right, patients rights, Patient Rights, patients' rights
# CUI: C3698592, Name: Patient's home
# Definition: <p>location where healthcare was delivered which is the residence of the Patient.</p>
# TUI(s): T073
# Aliases: (total: 1):
# 	 Patient's Residence
# CUI: C4527299, Name: Patient Decision
# Definition: A position, opinion or judgment reached after consideration by a patient.
# TUI(s): T078
# Aliases: (total: 1):
# 	 Patient's Decision
# CUI: C0030707, Name: Patients' Rooms
# Definition: Rooms occupied by one or more individuals during a stay in a health facility. The concept includes aspects of environment, design, care, or economics.
# TUI(s): T073
# Aliases (abbreviated, total: 13):
# 	 Patient Rooms, Room, Patients', Client's room (environment), Room, Patient, Patient's room, Client's room, Patient Room, patient room, Patients' Room, Rooms, Patients'
# CUI: C0042801, Name: Visitors to Patients
# Definition: Patients' guests and rules for visiting.
# TUI(s): T098
# Aliases: (total: 8):
# 	 Patients Visitors, Visitor, Patients', Patient Visitors, Visitors to Patient, Visitors, Patients', Patient's Visitors, Patients' Visitor, Patients' Visitors
# CUI: C0022885, Name: Laboratory Procedures
# Definition: Any procedure that involves testing or manipulating a sample of blood, urine, or other body substance in a laboratory setting.
# TUI(s): T059
# Aliases (abbreviated, total: 32):
# 	 Laboratory procedure (procedure), Test, Laboratory procedures -general (situation), Laboratory test (procedure), lab tests, lab test, General laboratory procedure, NOS, Laboratory procedure, Laboratory Procedures, laboratory testing
# CUI: C0039593, Name: Testing
# Definition: A procedure for critical evaluation; a means of determining the presence, quality, or truth of something.
# TUI(s): T169
# Aliases: (total: 4):
# 	 testing, testing method, Test, Testing
# CUI: C0392366, Name: Tests (qualifier value)
# Definition: None
# TUI(s): T170
# Aliases: (total: 7):
# 	 testing, tests, testings, Tests (qualifier value), test, tested, Tests
# CUI: C0683443, Name: tests and testing
# Definition: None
# TUI(s): T060
# Aliases: (total: 6):
# 	 tests and testing, tests tests, test testing, test tests, testing testing, test test
# CUI: C1704435, Name: Test Dosing Unit
# Definition: A dosing unit equal to the amount of active ingredient(s) needed to assess or examine the (potency of the) substance being used.
# TUI(s): T081
# Aliases: (total: 3):
# 	 TEST, Test, Test Dosing Unit
# CUI: C0242664, Name: husband
# Definition: A male partner in marriage.
# TUI(s): T099
# Aliases: (total: 6):
# 	 Husband, husbands, Husbands, husband, HUSBAND, Husband (person)
# CUI: C0555049, Name: Husband left home
# Definition: An indication that a male, married individual who is or was living with another person left their shared home.
# TUI(s): T033
# Aliases: (total: 3):
# 	 Husband left home (finding), Husband left home, Husband Left Home
# CUI: C0003052, Name: Animal Husbandry
# Definition: The science of breeding, feeding and care of domestic animals; includes housing and nutrition.
# TUI(s): T090
# Aliases: (total: 7):
# 	 Husbandry, Animal, Animal husbandry, Animal husbandry (procedure), Animal Husbandry, Husbandries, Animal, animal husbandry, Animal Husbandries
# CUI: C0310370, Name: Tomorrow
# Definition: None
# TUI(s): T109, T121
# Aliases: (total: 3):
# 	 tomorrow, Tomorrow, ToMORROW
# CUI: C0018235, Name: Grief reaction
# Definition: Normal, appropriate sorrowful response to an immediate cause. It is self-limiting and gradually subsides within a reasonable time.
# TUI(s): T041
# Aliases (abbreviated, total: 22):
# 	 Grief finding, Grief, mournful, Grief reaction, bereavement, mourning, Normal grief reaction to life event, grief reactions, sorrow, grieving
# CUI: C0030705, Name: Patients
# Definition: Individuals participating in the health care system for the purpose of receiving therapeutic, diagnostic, or preventive procedures.
# TUI(s): T101
# Aliases: (total: 8):
# 	 patient, Patients, PATIENT, LAY USER/PATIENT, Patient (person), patients, Patient, PT
# CUI: C1550655, Name: Specimen Type - Patient
# Definition: <p>A specimen that has been collected from a patient.</p>
# TUI(s): T031
# Aliases: (total: 1):
# 	 Patient
# CUI: C1578481, Name: Mail Claim Party - Patient
# Definition: None
# TUI(s): T078
# Aliases: (total: 1):
# 	 Patient
# CUI: C1578483, Name: Report source - Patient
# Definition: None
# TUI(s): T078
# Aliases: (total: 1):
# 	 Patient
# CUI: C1578484, Name: Relationship modifier - Patient
# Definition: None
# TUI(s): T078
# Aliases: (total: 1):
# 	 Patient
# CUI: C0239110, Name: Consciousness clear
# Definition: None
# TUI(s): T033
# Aliases: (total: 6):
# 	 alert, CONSCIOUSNESS, CLEAR, alerted, alerts, alerting, ALERT
# CUI: C3665546, Name: Alert
# Definition: Condition of heightened watchfulness or preparation for action.
# TUI(s): T169
# Aliases: (total: 1):
# 	 Alert
# CUI: C4084853, Name: How True Feel Alert Right Now
# Definition: A question about the degree to which an individual feels alert right now.
# TUI(s): T170
# Aliases: (total: 3):
# 	 Alert, How True Feel Alert Right Now, How Alert at Present
# CUI: C4553014, Name: System Alert
# Definition: A high-priority signal that is sent to a specific person by way of a system, according to an established set of rules.
# TUI(s): T077
# Aliases: (total: 3):
# 	 System Alert, Warning, alert
# CUI: C1553537, Name: Age Alert
# Definition: <p>Proposed therapy may be inappropriate or contraindicated due to patient age</p>
# TUI(s): T169
# Aliases: (total: 1):
# 	 Age Alert
# CUI: C0234422, Name: Awake
# Definition: None
# TUI(s): T033
# Aliases: (total: 6):
# 	 awake, Awake, Wide awake, Clear consciousness, Awake (finding), awakes
# CUI: C0028678, Name: nursing therapy
# Definition: Used with diseases for nursing care and techniques in their management. It includes the nursing role in diagnostic, therapeutic, and preventive procedures.
# TUI(s): T061
# Aliases: (total: 2):
# 	 nursing care, nursing
# CUI: C0028682, Name: Care given by nurses
# Definition: Care given to patients by nursing service personnel.
# TUI(s): T058
# Aliases: (total: 4):
# 	 nursing care, Nursing Care, Nursing care, NOS, Care, Nursing
# CUI: C0006147, Name: Breast Feeding
# Definition: The nursing of an infant at the breast.
# TUI(s): T040
# Aliases (abbreviated, total: 24):
# 	 breast fed infant, BF - Breastfed, Breast fed, breastfeedings, breastfeeding, Infant breastfed, breastfeed, breast fed, Breast fed (finding), breast fed infants
# CUI: C0028677, Name: Discipline of Nursing
# Definition: The field of nursing care concerned with the promotion, maintenance, and restoration of health.
# TUI(s): T091
# Aliases (abbreviated, total: 15):
# 	 nursing (field), Nursing Field, NURSING, nursing field, Nursings, Nursing occupation (occupation), Discipline of Nursing, nursing occupations, nursing occupation, Nursing Profession
# CUI: C0557523, Name: Cardiovascular Nursing
# Definition: A specialty concerned with the nursing care of patients suffering from disorders of the CARDIOVASCULAR SYSTEM as well as those identified as at risk for adverse cardiac or vascular events.
# TUI(s): T091
# Aliases (abbreviated, total: 13):
# 	 Cardiovascular Nursing, Nursing, Coronary Care, Cardiac/Vascular Nursing, cardiovascular nursing, Nursing, Cardiac, Cardiac Nursing, Cardiac Vascular Nursing, Nursing, Cardiac Vascular, nursing cardiovascular, Coronary Care Nursing
# CUI: C0442519, Name: Home environment
# Definition: A person's permanent place of residence.
# TUI(s): T082
# Aliases (abbreviated, total: 15):
# 	 Home, house [environment], Private home, dwellings, Domestic, Home (environment), Domestic (environment), home, houses, house
# CUI: C1547197, Name: Organization unit type - Home
# Definition: None
# TUI(s): T092
# Aliases: (total: 1):
# 	 Home
# CUI: C1548341, Name: Visit User Code - Home
# Definition: None
# TUI(s): T170
# Aliases: (total: 1):
# 	 Home
# CUI: C1548530, Name: Person location type - Home
# Definition: None
# TUI(s): T082
# Aliases: (total: 1):
# 	 Home
# CUI: C1549632, Name: Address type - Home
# Definition: None
# TUI(s): T078
# Aliases: (total: 1):
# 	 Home
# CUI: C0002766, Name: Pain management
# Definition: A form of therapy that employs a coordinated and interdisciplinary approach for easing the suffering and improving the quality of life of those experiencing pain.
# TUI(s): T061
# Aliases (abbreviated, total: 29):
# 	 therapy, pain, Pain Control, controlling pain, pain controll, pain relieved, Pain Management, Pain management, pain controlling, analgesias, Pain--Treatment
# CUI: C1304888, Name: Pain control
# Definition: Actions performed to support responses to injury or damage
# TUI(s): T061
# Aliases: (total: 5):
# 	 Pain Control, Pain control, Pain control (procedure), Controlling pain, pain control
# CUI: C1171175, Name: Acute pain control
# Definition: Actions performed to control physical suffering, hurting, or distress
# TUI(s): T061
# Aliases: (total: 4):
# 	 Controlling acute pain, Acute Pain Control, Relieving acute pain, Acute pain control (procedure)
# CUI: C0009932, Name: Control Groups
# Definition: Groups that serve as a standard for comparison in experimental studies. They are similar in relevant characteristics to the experimental group but do not receive the experimental intervention.
# TUI(s): T096
# Aliases: (total: 7):
# 	 Groups, Control, Control Groups, Control Group, control experiments, Control, control group, Group, Control
# CUI: C0308718, Name: CONTROL veterinary product
# Definition: brand of veterinary product
# TUI(s): T121
# Aliases: (total: 2):
# 	 CONTROL, CONTROL [brand name]

# %% [markdown]
#  # 4. Working with en_ner_bc5cdr_md using Disease - Chemical labels

# %%
nlp = spacy.load("en_ner_bc5cdr_md")

# %%
doc=nlp(sample)

# %%
for ent in doc.ents:
    print(ent.text, ent.start_char, ent.end_char, ent.label_)
# Out:
# back pain 26 35 DISEASE
# sleepiness 40 50 DISEASE
# hypertension 277 289 DISEASE
# urinary incontinence 302 322 DISEASE
# dementia 324 332 DISEASE
# chronic back pain 338 355 DISEASE
# excruciating 430 442 DISEASE
# pain 448 452 DISEASE
# back pain 496 505 DISEASE
# pain 620 624 DISEASE
# pain 838 842 DISEASE
# cries 871 876 DISEASE
# pain 954 958 DISEASE
# fever 1111 1116 DISEASE
# cough 1118 1123 DISEASE
# chest pain 1125 1135 DISEASE
# diarrhea 1137 1145 DISEASE
# dysuria 1147 1154 DISEASE
# polyuria 1158 1166 DISEASE
# pain 1310 1314 DISEASE
# hypertension 1731 1743 DISEASE
# dementia 1745 1753 DISEASE
# urinary incontinence 1755 1775 DISEASE
# chronic back pain 1777 1794 DISEASE
# degenerative joint disease of the spine 1800 1839 DISEASE
# diabetes 1856 1864 DISEASE
# stroke 1866 1872 DISEASE
# coronary artery disease 1876 1899 DISEASE
# hydrocodone 2122 2133 CHEMICAL
# Flexeril 2159 2167 CHEMICAL
# Xanax 2195 2200 CHEMICAL
# Neurontin 2253 2262 CHEMICAL
# propranolol 2285 2296 CHEMICAL
# oxybutynin 2316 2326 CHEMICAL
# Namenda 2350 2357 CHEMICAL
# Aricept 2380 2387 CHEMICAL
# alcohol abuse 2562 2575 DISEASE
# smoking 2579 2586 CHEMICAL
# back pain 3020 3029 DISEASE
# compression fracture 3112 3132 DISEASE
# degenerative joint disease 3198 3224 DISEASE
# Vasovagal syncope 3528 3545 DISEASE
# Osteoporosis 3622 3634 DISEASE
# compression fracture 3656 3676 DISEASE
# pain 3704 3708 DISEASE
# Hypertension 3714 3726 DISEASE
# hypotension 3732 3743 DISEASE
# Dementia 3782 3790 DISEASE
# Alzheimer type 3804 3818 DISEASE
# KCl 4080 4083 CHEMICAL
# Protonix 4089 4097 CHEMICAL
# Namenda 4145 4152 CHEMICAL
# Aricept 4157 4164 CHEMICAL
# hydrocodone 4193 4204 CHEMICAL
# Flexeril 4223 4231 CHEMICAL
# gabapentin 4253 4263 CHEMICAL
# pain 4308 4312 DISEASE
# Percocet 4326 4334 CHEMICAL
# morphine 4352 4360 CHEMICAL
# calcium 4403 4410 CHEMICAL
# vitamin D 4416 4425 CHEMICAL
# pain 4724 4728 DISEASE

# %%
data['notes'][0]
# Out:
# '2-D M-MODE: , ,1.  Left atrial enlargement with left atrial diameter of 4.7 cm. 2.  Normal size right and left ventricle. 3.  Normal LV systolic function with left ventricular ejection fraction of 51%. 4.  Normal LV diastolic function. 5.  No pericardial effusion. 6.  Normal morphology of aortic valve, mitral valve, tricuspid valve, and pulmonary valve. 7.  PA systolic pressure is 36 mmHg. DOPPLER: , ,1.  Mild mitral and tricuspid regurgitation. 2.  Trace aortic and pulmonary regurgitation.'

# %% [markdown]
# # 5. UMLS CUI Tagging

# %%
linker = UmlsEntityLinker(resolve_abbreviations=True)

# %%
nlp.add_pipe("scispacy_linker", config={"resolve_abbreviations": True, "linker_name": "umls"})

# %%
doc = nlp(data['notes'][0])

# %%
for ent in doc.ents:
    print(ent)
# Out:
# atrial enlargement
# mitral and tricuspid regurgitation
# pulmonary regurgitation

# %%
# running the following code takes a lot of time in doc = nlp(iter) part.
CUI_codes=[]
for i in range(len(data['notes'])):
    CUI_codes.append([])
    doc=nlp(data['notes'][i]) # Takes a lot of time
    for ent in doc.ents:
        for umls_ent in ent._.umls_ents:
            CUI_codes[i].append((tuple((ent,umls_ent))))

# %% [markdown]
# # Entity atrial is linked to 5 CUI codes. Trying to pick up the cui with max probability

# %%
CUI_codes
# Out:
# [[(atrial enlargement, ('C0741276', 0.9999999403953552)),
#   (atrial enlargement, ('C2348360', 0.9999999403953552)),
#   (atrial enlargement, ('C0232310', 0.928627073764801)),
#   (atrial enlargement, ('C0238705', 0.928627073764801)),
#   (atrial enlargement, ('C0232308', 0.9106837511062622)),
#   (mitral and tricuspid regurgitation, ('C0040961', 0.8772329092025757)),
#   (mitral and tricuspid regurgitation, ('C0026266', 0.78549724817276)),
#   (mitral and tricuspid regurgitation, ('C4527152', 0.7252084016799927)),
#   (pulmonary regurgitation, ('C0034088', 0.9999999403953552)),
#   (pulmonary regurgitation, ('C0265833', 0.8673610091209412)),
#   (pulmonary regurgitation, ('C3838801', 0.7916789054870605)),
#   (pulmonary regurgitation, ('C4288346', 0.7679407596588135))]]

# %%
# picking the one with max probability. Crashes in local. Moved back to google colab. 
## 99999999999 represents absence of a cui
CUI_codes=[]
for i in range(len(data['notes'])):
    print(i, flush = True)
    CUI_codes.append([])
    doc=nlp(data['notes'][i]) # Takes a lot of time
    for ent in doc.ents:
        if len(ent._.umls_ents) > 0:
            CUI_codes[i].append((tuple((ent,ent._.umls_ents[0]))))
        else:
            CUI_codes[i].append((tuple((ent,99999999999))))
